# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlesPlusC/RadMapJAX/blob/main/Ray2ForceConfig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import jax.numpy as jnp
from jax import grad, value_and_grad, jit
from jax import random
from jax import lax

from collections import namedtuple

import os
import time

import plotly.express as px
import plotly.graph_objects as go

def normalize(x):
  return x / jnp.linalg.norm(x, axis = -1)[...,jnp.newaxis]

def visualize_rays(positions, directions, length=0.1, max_rays=1000):
    end_points = positions + length * directions

    positions = positions[100:200]
    end_points = end_points[100:200]

    fig = go.Figure()
    for start, end in zip(positions, end_points):
        fig.add_trace(go.Scatter3d(x=[start[0], end[0]],
                                   y=[start[1], end[1]],
                                   z=[start[2], end[2]],
                                   mode='lines',
                                   line=dict(color='blue', width=2)))

    fig.update_layout(title="Ray Visualization",
                      scene=dict(aspectmode='data'),
                      showlegend=False)
    fig.show()

Ray = namedtuple("Ray", "position direction")

def spherical_to_carthesian(spherical):
  x = -jnp.cos(spherical[:,:,0]) * jnp.cos(spherical[:,:,1])
  y = -jnp.cos(spherical[:,:,0]) * jnp.sin(spherical[:,:,1])
  z = -jnp.sin(spherical[:,:,0])
  return jnp.stack((x, y, z), axis = -1)

def grid(shape):
  u = jnp.linspace(0, 1, shape[1])
  v = jnp.linspace(0, 1, shape[0])
  theta, phi = jnp.meshgrid(v, u)
  return jnp.stack((theta, phi)).T

def sphere(shape):
  spherical = grid(shape) * jnp.array([jnp.pi, 2 * jnp.pi]) - jnp.array([-jnp.pi/2, 0])
  return spherical_to_carthesian(spherical)

class Mesh:
  def __init__(self, filename):
    self.vertices = ()
    self.faces = ()
    for line in open(filename, "r"):
      if(line.startswith("v ")):
        values = line.split()
        self.vertices = self.vertices + (tuple(float(x) for x in values[1:4]),)
      if(line.startswith("f ")):
        values = line.split()
        face = ()
        for v in values[1:4]:
          values2 = v.split('/')
          face = face + (int(values2[0]) - 1,)
        self.faces = self.faces + (face,)

    self.vertices = jnp.array(self.vertices)
    self.faces = jnp.array(self.faces)

    box_min = jnp.min(self.vertices, axis = 0)
    box_max = jnp.max(self.vertices, axis = 0)
    box_size = box_max - box_min
    box_center = (box_min + box_max) / 2
    self.vertices = 1 * (self.vertices - box_center) / box_size

    self.build_area_sampling()

  def heron(self, sides):
    semiperimeter = (sides[0] + sides[1] + sides[2])/2
    result = 0
    result += semiperimeter * (semiperimeter - sides[0])
    result += semiperimeter * (semiperimeter - sides[1])
    result += semiperimeter * (semiperimeter - sides[2])
    return jnp.sqrt(result)

  def build_area_sampling(self):
    self.proto_size = 100_000

    vertex0 = self.vertices[self.faces[...,0]]
    vertex1 = self.vertices[self.faces[...,1]]
    vertex2 = self.vertices[self.faces[...,2]]
    sides = jnp.array([vertex0 - vertex1, vertex1 - vertex2, vertex2 - vertex0])
    sides = sides ** 2
    sides = jnp.sum(sides, axis = -1)
    areas = self.heron(sides)
    cummulative_area = jnp.cumsum(areas)
    pdf = cummulative_area / cummulative_area[-1]

    proto = jnp.linspace(0, 1, self.proto_size)
    self.proto_indices = jnp.searchsorted(pdf, proto)

  def get_normal(self, face):
    vertex0 = self.vertices[face[...,0]]
    vertex1 = self.vertices[face[...,1]]
    vertex2 = self.vertices[face[...,2]]
    v0v1 = vertex1 - vertex0
    v0v2 = vertex2 - vertex0
    return jnp.cross(v0v1, v0v2)

  def intersect(self, rays, t_min, t_max):

    def intersect_tri(face, best_ts, best_normals):
      vertex0 = self.vertices[face[0]]
      vertex1 = self.vertices[face[1]]
      vertex2 = self.vertices[face[2]]

      v0v1 = vertex1 - vertex0
      v0v2 = vertex2 - vertex0

      plane_normal = jnp.cross(v0v1, v0v2)

      plane_d = -jnp.sum(vertex0 * plane_normal, axis = -1)

      normal_dot_origin = jnp.sum(rays.position * plane_normal, axis = -1) + plane_d
      normal_dot_direction = jnp.sum(rays.direction * plane_normal, axis = -1)
      tri_ts = -normal_dot_origin / normal_dot_direction

      hit = rays.position + tri_ts[...,jnp.newaxis] * rays.direction

      edge0 = vertex1 - vertex0;
      edge1 = vertex2 - vertex1;
      edge2 = vertex0 - vertex2;
      vp0 = hit - vertex0;
      vp1 = hit - vertex1;
      vp2 = hit - vertex2;
      c0 = jnp.cross(edge0, vp0)
      c1 = jnp.cross(edge1, vp1)
      c2 = jnp.cross(edge2, vp2)
      f0 = jnp.sum(c0 * plane_normal, axis = -1)
      f1 = jnp.sum(c1 * plane_normal, axis = -1)
      f2 = jnp.sum(c2 * plane_normal, axis = -1)
      tri_ts = jnp.where(f0 > 0, tri_ts, float('nan'))
      tri_ts = jnp.where(f1 > 0, tri_ts, float('nan'))
      tri_ts = jnp.where(f2 > 0, tri_ts, float('nan'))

      skip = (jnp.isnan(tri_ts)) | (tri_ts > best_ts) | (tri_ts < t_min)
      best_ts = jnp.where(skip, best_ts, tri_ts)
      best_normals = jnp.where(skip[...,jnp.newaxis], best_normals, plane_normal)
      return best_ts, best_normals

    def intersect_for_i(index, state):
      best_ts = state[0]
      best_normals = state[1]
      state = intersect_tri(self.faces[index], best_ts, best_normals)
      return state

    best_ts = jnp.full(rays.position.shape[:-1], float('nan'))
    best_normals = jnp.zeros_like(rays.position)

    startTime = time.time()
    state = (best_ts, best_normals)
    state = lax.fori_loop(0, self.faces.shape[0], intersect_for_i, state)
    time_taken = time.time() - startTime

    ray_count = (rays.position.size / rays.position.shape[-1]) / (1000 * 1000)
    intersection_count = self.faces.shape[0] * ray_count
    rays_per_second = intersection_count / time_taken
    #print("{:0.1f} Mrays/s ({:0.1f}M rays in {:0.3f}s)".format(rays_per_second, intersection_count, time_taken))

    return state

class Log:

  def flatten(self, vertices):
    vertices = jnp.reshape(vertices, (-1, vertices.shape[2]))
    return vertices

  def init(self, vertices):
    vertices = self.flatten(vertices)
    self.path = jnp.empty((0,) + (vertices.shape[0],) + (vertices.shape[-1],))

  def add(self, new_vertices):
    new_vertices = self.flatten(new_vertices)
    self.path = jnp.append(self.path, new_vertices[jnp.newaxis,...], axis = 0)

  def plot(self):
    depths = jnp.arange(0, self.path.shape[0])
    depths = jnp.repeat(depths, self.path.shape[1])
    index = jnp.arange(0, self.path.shape[1])
    index = jnp.tile(index, self.path.shape[0])

    flat = jnp.reshape(self.path, (-1, self.path.shape[2]))

    data_frame = {
      "x": flat[:,0],
      "y": flat[:,1],
      "z": flat[:,2],
      "depth": depths,
      "index": index
    }

    scene = dict(
      aspectratio = dict(x = 1, y = 1, z = 1),
      aspectmode = "manual",
      xaxis = dict(range=[-1,1]),
      yaxis = dict(range=[-1,1]),
      zaxis = dict(range=[-1,1]),
    )

    fig1 = px.scatter_3d(data_frame, x = "x", y = "y", z = "z", color = "depth")
    fig1.update_layout(scene=scene)
    fig2 = px.line_3d(data_frame, x = "x", y = "y", z = "z", color = "index")
    fig2.update_layout(scene=scene)

    fig3 = go.Figure(data=fig1.data + fig2.data)
    fig3.show()

class NullLog(Log):
  def init(self, vertices):
    pass

  def add(self, new_vertices):
    pass

  def plot(self):
    pass

class World:

  def __init__(self):
    self.position_key = random.PRNGKey(0)
    self.index_key = random.PRNGKey(1)
    self.direction_key = random.PRNGKey(2)
    self.mesh = Mesh("GPS2F_v6_full.obj")
    #self.mesh = Mesh("box.obj")
    self.light_position = jnp.array([0.9, -0.3, 0.4])

  def sample_directions(self, shape):
    self.direction_key, subkey = random.split(self.direction_key)
    return normalize(2 * random.uniform(subkey, (shape[0], 3)) - 1)

  def sample_camera(self, sample_shape):
    a = 2 * grid(sample_shape) - jnp.array([1,1])
    b = -5 * jnp.ones(sample_shape)
    positions = jnp.concatenate((a, b[...,jnp.newaxis]), axis = -1)
    directions = jnp.ones_like(positions) * jnp.array([0,0,1])
    return Ray(positions, directions)

  def sample_light(self, sample_shape):
    self.position_key, subkey = random.split(self.position_key)
    xi = random.uniform(subkey, sample_shape + (3+3,))
    directions = normalize(sphere(sample_shape) + 0 * xi[...,0:3])
    positions = 0.01 * (xi[...,3:] - 0.5) - 3 * directions
    # visualize_rays(positions, directions)
    return Ray(positions, directions)

  def sample_surface(self, sample_shape):
      self.index_key, subkey = random.split(self.index_key)
      xi = random.uniform(subkey, sample_shape + (3,))

      face_indices = self.mesh.proto_indices[jnp.array(xi[...,0] * self.mesh.proto_size, dtype = int)]

      sampled_faces = self.mesh.faces[face_indices]
      sampled_vertex0 = self.mesh.vertices[sampled_faces[...,0]]
      sampled_vertex1 = self.mesh.vertices[sampled_faces[...,1]]
      sampled_vertex2 = self.mesh.vertices[sampled_faces[...,2]]

      edge0 = sampled_vertex1 - sampled_vertex0
      edge1 = sampled_vertex2 - sampled_vertex0

      bounded_xi = jnp.where(xi[...,1,jnp.newaxis] + xi[...,2,jnp.newaxis] < 1, xi, 1 - xi)
      positions = sampled_vertex0 + bounded_xi[...,1,jnp.newaxis] * edge0 + bounded_xi[...,2,jnp.newaxis] * edge1
      directions = sphere(sample_shape)
      normals = normalize(jnp.cross(edge0, edge1))

      return Ray(positions, directions), normals

  def intersect(self, rays, t_min = 0.1, t_max = 100):
    ts, normals = self.mesh.intersect(rays, t_min, t_max)
    return ts, normalize(normals)

def ray_to_force(incoming_direction, outgoing_direction, normal, specular=1.0, reflectivity=1.0, normal_only=False):
    speed_of_light = 1

    if normal_only:
        magnitude = jnp.linalg.norm(incoming_direction, axis=-1)
        magnitude_reshaped = magnitude[..., jnp.newaxis]
        force = magnitude_reshaped * normal / speed_of_light
        return force

    if not 0 <= specular <= 1 or not 0 <= reflectivity <= 1:
        raise ValueError("Specular and reflectivity values must be between 0 and 1")

    diffuse = 1 - specular

    specular_force = (incoming_direction + reflectivity*(outgoing_direction)) * specular
    diffuse_force = (incoming_direction + reflectivity*(1.0 / 3.0 * normal)) * diffuse

    total_force = (specular_force + diffuse_force) / speed_of_light

    return total_force

def reflect(d, n):
  return normalize(d - 2 * jnp.sum(normalize(d) * normalize(n), axis = -1)[...,jnp.newaxis] * n)

def estimate_backward(sample_shape, world, number_of_bounces, log, force_config):

  rays, normals = world.sample_surface(sample_shape)

  log.init(rays.position)
  log.add(rays.position)

  incoming_direction = rays.direction
  outgoing_direction = reflect(rays.direction, normals)
  force = ray_to_force(incoming_direction, outgoing_direction, normals, **force_config)

  for bounce_index in range(0, number_of_bounces):
    best_ts, best_normals = world.intersect(rays)

    new_position = rays.position + best_ts[...,jnp.newaxis] * rays.direction
    new_direction = reflect(rays.direction, -best_normals)
    rays = Ray(new_position, new_direction)

    log.add(rays.position)

  is_back = jnp.sum(jnp.nan_to_num(normalize(incoming_direction), 0) * normals, axis = -1) > 0
  is_hit = jnp.any(jnp.isnan(rays.position), axis = -1)
  force = jnp.where(jnp.logical_or(is_hit, is_back)[...,jnp.newaxis], force, 0)

  log.plot()

  return force

def estimate_forward(sample_shape, world, number_of_bounces, log):

  rays = world.sample_light(sample_shape)

  log.init(rays.position)
  log.add(rays.position)

  for bounce_index in range(0, number_of_bounces):
    best_ts, best_normals = world.intersect(rays)
    rays = Ray(rays.position + best_ts[...,jnp.newaxis] * rays.direction, rays.direction)
    log.add(rays.position)
    rays = Ray(rays.position, normalize(reflect(normalize(rays.direction), -normalize(best_normals))))

  log.plot()

  #radiance = jnp.where(jnp.any(jnp.isnan(rays.direction), axis = -1)[...,jnp.newaxis], 0, rays.direction)
  #radiance = rays.direction
  #radiance = jnp.nan_to_num(rays.direction, 0)
  radiance = jnp.nan_to_num(best_normals, 0)

  return radiance

def reconstruct(radiance):
  return radiance

world = World()

# def downsample(image):
#   result = 0
#   result += jnp.roll(image, (0, 0), axis=(0,1))
#   result += jnp.roll(image, (1, 0), axis=(0,1))
#   result += jnp.roll(image, (0, 1), axis=(0,1))
#   result += jnp.roll(image, (1, 1), axis=(0,1))
#   result = result[::2,::2]
#   return result / 4

def downsample(image):
    from scipy.ndimage import zoom
    # Calculate the necessary zoom factors for each dimension
    height, width, _ = image.shape
    zoom_factor = (181 / height, 361 / width, 1)

    # Resize the image using the zoom factor
    resized_image = zoom(image, zoom_factor, order=1)  # Using bilinear interpolation (order=1)

    return resized_image

def calculate_rms_difference(image1, image2):
    # Ensure the images have the same shape
    if image1.shape != image2.shape:
        print(f"image shape 1{image1.shape};image shape 2{image2.shape} ")
        raise ValueError("Images must have the same shape for RMS calculation.")

    # Calculate the squared difference
    diff_squared = jnp.square(image1 - image2)

    # Calculate the mean of the squared differences
    mean_diff_squared = jnp.mean(diff_squared)

    # Return the square root of the mean
    return jnp.sqrt(mean_diff_squared)

def load_and_display_jnp_file(file_path):
    # Load the JNP file
    rgb_array = jnp.load(file_path)

    flipped_image = rgb_array[::-1, :, :]

    # Print the shape of the array
    print(f"Shape of the array: {rgb_array.shape}")

    return flipped_image

solution_shape = (1000, 2000)

def build_force_map(sample_count, estimator, force_config, number_of_bounces=2, profile_interval=1, save_path="/content/images"):
    import matplotlib.pyplot as plt
    import numpy as np
    import os
    import jax.numpy as jnp
    import time

    solution = jnp.zeros(solution_shape + (3,))
    total_time = 0

    if not os.path.exists(save_path):
        os.makedirs(save_path)

    for i in range(0, sample_count):
        startTime = time.time()
        radiance = estimator(solution_shape, world, number_of_bounces, NullLog(), force_config)
        solution = solution + reconstruct(radiance)
        time_taken = time.time() - startTime
        total_time += time_taken

        if i % profile_interval == 0:
          sample_count = (solution.size) / (1000 * 1000)
          samples_per_second = sample_count / time_taken
          print("Step {} [total time {:0.1f}s]: {:0.1f} Msamples/s ({:0.1f}M samples in {:0.3f}s)".format(i, total_time, samples_per_second, sample_count, time_taken))

        def tonemap(radiance):
            return (radiance - radiance.min()) / (radiance.max() - radiance.min())

        image = solution / (i + 1)
        image = downsample(image)
        image = tonemap(image)
        fig = px.imshow(image)
        fig.show()

        # Save the image
        image_np = np.array(image)
        plt.imshow(image_np)
        plt.axis('off')  # Turn off axis
        image_filename = os.path.join(save_path, f"image_{i:04d}.png")
        plt.savefig(image_filename, bbox_inches='tight', pad_inches=0)
        plt.close()

    force_map_filename = "force_map"
    for key, value in force_config.items():
        force_map_filename += f"_{key}{value}"
    force_map_filename += ".npy"
    force_map_full_path = os.path.join(save_path, force_map_filename)

    np.save(force_map_full_path, np.array(solution))
    print(f"Force map saved to {force_map_filename}")



def create_gif_from_images(images_path, gif_path, duration=0.5):
    import imageio
    images = []
    for filename in sorted(os.listdir(images_path)):
        if filename.endswith('.png'):
            img_path = os.path.join(images_path, filename)
            images.append(imageio.imread(img_path))

    imageio.mimsave(gif_path, images, duration=duration, palettesize=256, subrectangles=True)

    print(f"GIF created at {gif_path}")

experiments = [
    {  # Surface Normals
        'specular': 1.0,
        'reflectivity': 0.0,
        'normal_only': True
    },
    {  # Only Specular
        'specular': 1.0,
        'reflectivity': 1.0
    },
    {  # Only Diffuse
        'specular': 0.0,
        'reflectivity': 1.0
    },
    {  # No reflections
        'specular': 0.0,
        'reflectivity': 0.0
    },
    {  # GPS2F Gold MLI Material
        'specular': 0.5,
        'reflectivity': 0.7
    }
]

for force_conf in experiments:
    build_force_map(100, estimate_backward, force_conf)
    print(f"built force map for: {force_conf}")

# create_gif_from_images('/content/images', '/content/force_map.gif')
# print("Done")
# Out:
# Step 0 [total time 19.6s]: 0.3 Msamples/s (6.0M samples in 19.606s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d961dbfd-6b45-471d-abb1-28007f7b8cca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d961dbfd-6b45-471d-abb1-28007f7b8cca")) {                    Plotly.newPlot(                        "d961dbfd-6b45-471d-abb1-28007f7b8cca",                        [{"name":"0","source":"...\u002fP9+K4LOXjwYHykpCTQ1DobbQ7+tXD6afgKYDlAK3zYEfwfYP\u002fpmnh1N2dTkFc\u002fCrOzwIsFA0DFi4B+31BPLEjb5Rk4xQSAJ6Lg2zloTYX1\u002fQAAHwL8jw\u002fwX4CXz8K+7U8fhb+GLoF8U4YR+o4BPG4DWQH8DUcAnto\u002fD\u002f+EAVjSlrMG7oGgDBZvf3OF+taGZwEOwUQA4l4F8a8w9h6sKYfG5TBvhzAPgBV2SyCaBBswkPABkD4D8EMO3HqxYJX4+INn25YpDsCgD1J9ALT7fW9WZXx7F6w1Fwphy8jfAJAUoI\u002fgRgHykYPL0XcQ+Mix8VfaZTbs1czJ6REfr4Vbp7pefT9H+ZP+Eyf\u002fnV6ATCjCgS4A1U74gwok+KoW3mmmw88L4GeCMXQG5nZAxKG7cc8SiqDyHHzggc9uA6yA\u002fy9vb2bHqt4ftsBrNW0S+Qc3Xqk7neR4O+pM8O2n8550q\u002fZnwNkXu\u002fAv5\u002fg\u002fAygFKAG4+kPUu+vKxvoC1mdPMfVd172Za4lIPbxXDl8AcAF+gZcK2L9+ZR7450qafwNTBtZnoaeEeyPXeJAK+wE+PQKWpyDZBrClFe4V1nqhmgcT0xdp726W\u002fKOEcy5oSaj6TnIfv9DsW7rkxxvwdq2JutNPdwm\u002fA94TcDYKlh3wsr8vfWe2PZkGa8AAwBMZftfyMADPAeXrZsvbdwmB\u002f93uPSres2\u002fHwaO128gD8L\u002fVMESHViPUaWFlAcSowRnxl\u002fjPpzVLXB5vIJIXUgy2XjWtuFEGGQ749juAPw7Nb332nZfAbUn\u002fsPizbGSwHnmv3AbXC2FtD5xyTxWSY6IArmJhfRAqAR5+Brff6Nz9di7\u002fe9jFhY++AfgFvh+CAvR+EVQpKkD+6IcReO0CFlgPoeU5OK8Bzjy8SA99Cq1ALb4SHDhFiN1xgrxp3Rkw7sjh3uyC5QDNAHeve7avJWWenIbd0fC8Exa4vXJP5hDAw7eh62toBdN\u002fQL+sEPegNXqjBy5\u002fCLDh\u002fsGaqtVu680Q8+NQEhwYARVsuQpFZOtrNUzkLqAAB1Hog8U9bMFGCwCMw3\u002f445cS4xUvl+ILG7+qhDMAfXAC4An4WA8H+WsBrn+Zo\u002frFfjdu\u002fKlvX4LsXyfgWBzsEcHBSfgYA7l5UDMM93zQIQA8748nBp4nroKXRBB25gcGvIYAFELtve+q6REAmwAqIeEhjMHPkPsydEITQBvNddJBGdf\u002fuUX33ImUKYAY6AFi1pfehneh7Itk3XuJO+FiHbzJTvt29IX1Ec\u002fFKuHIVxHmr+eW4253oCvNYwBfgZoA0kMAYK8mDhUTCpHX\u002f+8gHZ0Tx4tRI\u002fF3lWWjuFtgnliE5yFy9OGI7b4ov8WBaeSE6NHOwjZqD7RyMgsnlVaMcSwgducnlqgb5sI9KZ7wll4NaetU0idC1RMk2QIGwoNwPgbWTrt68R4AjnGfTHz9tE+ZD2pidWKrj5L2m526tH+C\u002f0zccT0v02YAZ1MROR249MZxOpl0078qPrFF3DE3HUWLliZA3wh0lVtzppnvzsOXhbAuANdmIWnxfAb63GmSKXcJuGdgaL4dIhjCshWM4xpdyGtDmwkxzOwRY+tc+buF8FJALbPGQXVvXm\u002fcg3j\u002frnbGjTrL5E5+bJJt7irE0nz+5O58bWG7YE6kzNbarwkpcp03TDYOqvnA8NO6\u002fWnS+q65SUtEVIqLdsFRwRM8Ik6ljZe\\u002fXoTIM4zctD5wAiYG6UI0k0BfjGsbmpnEhBaEjbwyxMRwDbAINPMhPirWn10NcGC2+3RjYWAhTPQItzSM7SKSRLA+5xLyE1QPBNZ+Ojn5pmPu8bgnm3B19FqLNgDmqblNM6bnEi0QyF7NhJao+2roAUArQIkDkMSUPDZpkfTqpiXPJuJqyJF0+PabYox4d3bRzoUsTJjQQgqmGMOfFUb9zhTLBKZXxdY8ztKF1mB3shQCgjjnUXxm32tQ\u002fXFt6rFiX90avfHIvjM\u002fvMrWvmwr2ZcjX0x0P1wsJjXOyUnl2zW\u002fXgXHeSZDEsYcV0HT20A5d4\\u002fGuvTlgEIZsKfROJB95M\u002fs7W9dj5K3kAXu2nXschRZTM8L+QXsSIhUokAjqbsTRNdBZeHaNJAKBKKZjUgpgB5u\u002fbQoQHpOB\u002f5pFmASVmHXkzAPecKs5WSqUTyeh8bTDlrof6I9gJ78lHlDA+rFMu44E7K2Bl5PUi5XIHgs+ruiIeXTzxYma0IwR9I1TSACRkM2e\u002f5n0JgO\u002fGP26HgPWrEUy+yG8ow0DXo996VD7AtMFCIn41bxL59wjVtSe+AJlLSvOvJsTBlz5YS5S6SRZc7YXXTC5HA\u002f6GvwVO+MsFPKiFiCpwvkfABwpTxlwwFqEVGFX4JTprmN2PMW4G\u002fLGhOKWonQ4UfMSkze19TBqSCm7goA1i+uNVz3BJhL6zw4G1Rr4K6wcaxhOLNcXO42q9PzLTV7gJpRfVxvy+qPEbR5wxQoDSqcF0ABthabSH\u002fHJ4vj2X4KJR1JyYhPYxH4y2A2Bu3sXV\u002fEts9ACb ...
# Step 1 [total time 38.9s]: 0.3 Msamples/s (6.0M samples in 19.336s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5d482ae6-eb41-468a-8ced-823a8c72eac5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d482ae6-eb41-468a-8ced-823a8c72eac5")) {                    Plotly.newPlot(                        "5d482ae6-eb41-468a-8ced-823a8c72eac5",                        [{"name":"0","source":"...\u002fHdy9db49rwwRtaRP6vucNXlZclleE1IKw483PHgzPQYbZ64ZryS2n2g9vAlmXbGJvszOZfMXEqCXwZNo6P0tQd489UwT\u002fzgG8GZX2w8BSqfUQCiwCQFwDyu8D69TcB0Rd\u002fPQ78K3AMTPm1d4DCdwDgJ8vzknPRjeNVqOeccCh7ktsnvStnsCIDDGWER\u002fE\u002fTVYvvHTec\u002fdIbkHIPgnALqDyMv0bvwVHHMCn+PKl7vUNpj0qWpYj594ET55f8qIHwKM6Q8ofHB2cS2Kxr6dbjUnHcUflR3qAI\u002fqWyfHajyNrRmcaApz09gQPUB1wyyMfaYyvFB1O4HZs5azx2zflewRxzrg8jJx7MtJ9I1+fd2ikxf7PQ\u002fznsyeFF7wz72o6p4Gj4xggECBLy2vvT3f1vGs4TJ8BuusHQKMKXAQex84pvwR4vgucGbC5AShkgV3DEVAuGxpfzGYLrRcAsSMjLJ8J3Yy9oiLfOH2g+uspw1il9Ste6cEnx3fm9NoHj5XquVLViCjeu7ikKd+pxLwqnEtuBfPznnOhxOkvWR9WAEAPAP8NmB3rPbl8WNzejCK\u002f6cAAzcdA3swvvdYZW69MAOj\u002f\u002fETy5eeByiiAiTI90EjejnL4jqrumJPwg71mLzpQflfg+OvBD2ChlXaY147Upx4kx56lY5vCVYjfG3n3CvBMjeaUzLcCWZU7+BWFaYMTFbp6xA6oFi6V0Dupm4tfgZkHs\u002fmd5m9MjPzhTkUiOUTmL8DpRrPU7ceJc1e1QP1Of\u002fCHh7ofTq0TOf1SQXrXHrDvfkyf+1\u002fTraE3xPfBIvDF95qWhW9\u002fatyG\u002fPfI7+n0B4nEn8xmgTd+E3gKBZZXaudguXKkVNh0IbzmuTiwnGZStgfjX+CN3J\u002f772LgD+7jN54TRUtkP54+Z8s0rGelP1xdHlvY0QALbzV\u002f9VuZI9zBU2OzP2HufyNDps1Rdvlru0s\u002fJA5fc8EHByP6c6E840KLzUnlN34E\u002fp5HIlhOzpxT1l4Py8W+wr8QWhsGiLSlm2Iq\u002fRNsbo61P9uSvWHrCIrH8xrqk9glk\u002f1n1OGXu8Q\u002fcOfNc4PxClrd7t+UrH5l6dy\u002fPQK+TgFOGAh4258rBb42AOxW9ucE+vdJpW7vHGBaBmyAFgBMwP7G\u002fqi85sfPHdvzQPRHC83\u002fLxSUVb+49jsh\u002fd8DwM1q8xWL5CtV4J9BYN4AYD4gHAKyDQDm\u002f9Ci\u002f7qiDSQEpcxWlMtdOMcFov1l9ea5dAwo\u002fS+cnxLxy4ADWF43uIB09KHjDJRdfjl1riJa9rfP7XuXgdo5IB9cU5Tnc0bAmsbpybkvC47fXD41\u002f9pK4xPvY+HIsfijL\u002frJnzZs55azvXM9AgBmgUkpcPNngKnWNzKlr14zgX\u002f8q18xiRVaGx5VcPbzIvvgJk9g6rdnrOrc3Sj97yzSQwER74k5No7rwXEcqPMmzjVjMUbNHeQ7p2SOSitOV6SgIly1e013kcf+wjCfVw0bUAtQbAKifp47kFJVHn1JLG+sVkIVJjnscHWqiKaFciS1HGnVZ7r7fdKhU2wPA35Rr\u002fGI69MG94ipvoZWNkqwoNih5I50Cso+jcIJ4E\\u002frzff5YJc51iAsLerDu8YRx4fvV+dUbXGkWfOJ5RSGS4VEVYDKYkA9LdGOCriyIABYTDCdoPuDztViIybNf0Dgl3tLrHegvUMmXYzJdLxJutYLcqcBuYQTucEJSMjAMqc\\u002fo4QKJvEikIS3JIQoz+vleOPG3BqsOKMuPUpr4LhQR\u002fBaZwCymGh0g1yFVanjkzhgBtw7dMLYqnWGnaYYnmiLdHmKrxKcmBqXCeED6IZT4UwecY3eIcmgFCnYlPqTelbWo3kSY0OYF88Z2is9eaJxIuhxmHMS9W6qqVDa0wJWeFLcdQ68BKKT1QGBIJjhCrN9wWluOFadgezREcRCFPNJjhjLBfRODEmORLU5UqAYEfGrsY1sSos7RTI7YY5P5aBoj8yzQmysScc4lU9F3jPJvEODMUBbmtanR+K8\u002finpnbXosArkS+Xl48IUqL\u002fjLgvVZrLNXaKfJHs2DZ+zvkeZhK07U9ALscZBG5302MoNpaBy1Jd2AQEqRCd3WhDH+CqPj9PcUjcSs3f\u002fnnx6vl8VcHrb6wnoxW+b9ptEThDjPxRc7KAkPm5Bl0wZQFeSIWFraQRdz0HOvEMGY3zDBLgLiiQiL+jNp3MjNFwpP54m4A6ks7+EWuykv52qxq8gqABRIylIU4lwJgZ4bERN40Cm\u002fDrPDrCquVoSWyo4rJ14VV03hgzxcMkM6OglR2EM4NHMq1i\u002f8RP4nVMQ+XahGAOYelpNaqxwe1So4K9EdVUGmAeAji\u002f\u002fo6M6b\u002fdmalctn6x2bVpaKJMCUJS9xPNHu3Q09P5bnQFpwAJcwiqkxD5+ehlo9GuWi2jDon0mblVXa9zpDls1yxTi9R74xAi4nsmNQyi0w6Hl0k1wayJtaPfwIFeFAE5Ed2uKjZ7NrAgz44jw7iHCrZsoJUTLVeJjao2rMPcPLO1WjE7rGqFtvqJ\u002f1PErSr1Mqn\u002fM46y3h2aX+vJApy3Eu9BELE\u002fHgigADFYjrvxduGIsIY0jS58TfkqBNghPFTT6qi ...
# Step 2 [total time 58.5s]: 0.3 Msamples/s (6.0M samples in 19.591s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fc6e2d5c-03c6-4389-a7b6-33388f2a81d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc6e2d5c-03c6-4389-a7b6-33388f2a81d7")) {                    Plotly.newPlot(                        "fc6e2d5c-03c6-4389-a7b6-33388f2a81d7",                        [{"name":"0","source":"...\u002f\u002fnPf5jxnsv47mNsbkmttsiyLDuJk3WcpJKh7GQyqa2BqmxqdmsnszVU62RDXrNlgdVSq1sN7\u002fVjuve9y3iYmX7m\u002fT7wb\u002f3j\u002fzX5fn\u002fdnFR\u002fwcObXwxfrF941zdmqy25nf6fLh19r9scVRfWL\u002f2jPvDXu+W9S7b3RUbLPbrmXZs2FQD2NSmYFdhPsOY\u002fjAKPmkyZH38gtA\u002fN+cVDAAwC+ui8PL8\u002fHf3+b7i2Pwe6wNxV9Hya+j9c5\u002f\u002f3H73n\u002f4PPdj\u002f1gJHhNb+rXvroIHzrugY74Ys9Yqv\u002fV6+F+MbMYkBh2mcmEQZ8wWbleujdn0FNGNjzPMpBbx\u002fnzxhGXDpYKi1L0XliVIf703lQ+WOUuFzpdlZluZcNHfi55ZYOLHceHwbmwc5T0OuxzsI2kDbJa120dekpBr\u002f3M4\u002f7zm6n5IbfU9mnPTzlPXzLzP3REuDuirth98XRzuOvLlz0NcZ\u002fL3rl33HNpcq9MjhD2\u002fB88+yFS\u002feEN5SpvcgMzp6zoCebBP64kkt\u002fEwt+AkCWfYGFRiLwMVVbkp6y+X\u002fR6BQrvw+sEIeE8Jb+upNzmQ8Wqq5fZjzJPeWNG8ujLx48znlcd0+Ma7mVcboS+A9hdwZqTFtRn1KBi6Mnsxd+szWYv94\u002fkRYB+lzazkVDtdEaNXm+dR97f8EB5v4UGP421s\u002fqubND2U6fPaFu\u002f2NgGjHQFyUjPGveayOR6wL\u002fwOjqSwbbqXmy\u002f1fL+bP+L5jRkvGWXahyV4567ov7rcJmG2zlk9pbTWUcCitOiwal4fF3uJma2m7PGjdKYH4wDyZ2+jtLt6HDIzpc4t64k\u002fiLT7zU5QcwsnLUl9Jnpgm+XErcAlZ3jeff20p8FjwPR3jieXn\u002fon25XCgtfe3C+Hc+d\u002f\u002fUN86mXpwNM29AwaOjjQfxP1x2iwfNG1cmd375945jY0Dbe74kX2EXJ2M1PF\u002ftxqfMFw\u002fto43jq1+v3Hr2jX8dPPxwC\u002fjkQgawULN7uBRApNUl+i\u002fOppnZz0aT1Rr6wY3Wx2hiWUVnHPsoOMx1fB9VdpaslYFZeyMEfZRPrL\u002fdfDoNrw36SSr7Z4GnNxX8FT3DDMXffciIb4x2RH6ZBjgF+SwlNB\u002fIeAa7dOUIfnBFTk2CLHe03UHcwQFejU3UU2LWl7PSgiboyl8N2\u002f8snPlJi\u002fyh0UcLvv3fFYt7TCx6CJT5ytIo\u002fUXaDn\u002fyW8atH6EBwA0APkAqFS5T6lTGXX7vYfsP57T\u002fotlICR+ef\u002f2w\u002fwmQey3I1\u002fzUbQ74jAXm6wCsAC1+MDS8odg9R3mTVYGz6sRarKPy0tJ9ALpe0v8k3RYBz79QmkESewokgMNDIOw49wD3906ln3ytf\u002fUcH87oKwP7UOSXgFHz7PLo5mN\u002fP\u002fAQ7n038W2w8PhH6yvv7QxfLN1d8tjk82\u002fHjZ++dC85r+WllHlIppYUrzLpkaFnBued\u002fu+JNvh\u002f+x\u002f+QXgUz8RaJzxyNggFrV950aBTnkEXpGardSXr0lWmiFIqXQ6XtbEAT+eX8GrfnQLbk\u002fGCk3bgGtLgVD4\u002f5ucir9jj2+0ZDRlW3KIbNiWNCimTEY02MM8aiqhHRlU3uon0mn4wRo2RC6OOve7IuVkxIC4VFmcHAcRoPHbFPXlF3+jTImsMPIGx1kz7RhUdneeUsvyfO\u002fD\u002fjxFDuFL1mqqsvVny\u002fQgzwx7AS5tIZTwgKD6dM0vnUDYA7Rw4gWx0UK96MjGGPNKPw9WMtlByd2aOnd4aye0oog25wjOQUaBbuOZFq6gy6lgRrychTBsYQcEtah6zftLt8TN62MyVNHPRHCmmKeJKliL3Nd3bSg\u002fj7Rcg9HW+r5VQgoWaDTrgaPpsbxZYGnZa9Rm01w2ugD2RMgQRYPVGK7CYkYhRS3b79b6D4AGpXYUw+wSBrhL8aLHvP\u002fcWjjrZLA\u002fGYG00HdBsWOsMVY7qwmqM1PDF0OMXcpZteM5keY5GHMYtYoM2hIU1WewnE6lOGCr3TL+HI+s9BpBnbT0\u002fBtq6ytkpJo7yx\u002f1j3owsysXjVMuZhqLYGyN4G6i7RKA9xcIbKXdBO\u002fUIi\u002f6g3muJKAiK2vg4Bll42D\u002fNG1p\u002f1uUITV\u002fXC7kEpM67N8rQLqmmKUNUhjZh0CA1YWLSdBz0qwAgSDUPidc1jnN6aZpX5caBPeszgURxsDvHriYC4unYkg148aH\u002f5GqVTNjuSnI8bgvBD4LWR0WSDk57XC0ZDJWexS\...\u002fljzQm1OvNzl84nTRjzZyjtnNQHtdEshKNIFAtX6hCC+ADmiEUGQqNxx\u002fwz88Jl2obFaOO0H1r4OlrZYxSzaXyurVoxcbAWzM2nJzqrYsOCZ+RlPzWkmUY8BJIG4tPqqu6Nz4hMsbrlNjBhehJVmU6TvzyH+IOpWbjtbl8dLuFozt6ftPvyNEMr+MIsrzED+S2ENyRgLt9rBcbrCxQocXtYNf6yBHIJ12BhXmEQXCRmsKNulbl\u002fCTbPD\\u002f7Ii9mEO30LXurEXOgER4\u002fW3C6pw2Onx9h4dOsBSHdega7zNi2U6La34w8fj4BjNf7nZohYZI9H1SKH66HAVEkOhZ6oxdiudh9hNkaLjhNdDmaRn\u002fd68pa\u002fFXQVf1ruOGdcyitGH8UK6sbZPlHy+4lMQ6LH\u002fiiAQp+jWlwA+lk\u002fycCGG6wDsymME7qcSp\u002femA4FZbKPZBswaQVFRQzO+vpYf9JfXWttpZjR+ebTi8YUajwbyeAvQva6eE2+ ...
# Step 3 [total time 77.9s]: 0.3 Msamples/s (6.0M samples in 19.365s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fffa4989-09ec-49db-806b-111aaa05767d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fffa4989-09ec-49db-806b-111aaa05767d")) {                    Plotly.newPlot(                        "fffa4989-09ec-49db-806b-111aaa05767d",                        [{"name":"0","source":"...\u002f3\u002fv29n37O9Jk7t2\u002fzmrW9xmaJjYkshZZICIkEKQpRkCAJSIggsDEY8K693t27t87c6XPm9HP+3v+v9\u002f72XvI84L\u002f7H\u002f3XhbfGVcu+\u002fJcU9\u002fYr6YZZe7Ch44MRP0\u002f\u002fFxuLj+ZXSu+j5Xu3xevH1\u002fDRun\u002frInOOHuwsoeokDVR4YKCzVuIJMnkrau6PwwNOeTs+A5rF4AoAS4Dbqff8pr3zB4+kT58BClD8HtLWMv853foff\u002fsQ+htPv\u002f0unrTH25uwI795Od7aoeBa+e2Q8YR\u002fcfYV\u002fdGj7U4HAEQXj874e+SAjTz4QuyV+UvtaNlJDQwf1AzuKuMsB\u002fdK2EvDORmsxPWfhcid4WK+BJhXacYjI7ddsxt9o1zdta3WFevRfSAS675FL\u002fMtcLL+82jib\u002f+Vw9y7Udpb\u002fuY31Dc0+oehesrP\u002f08MW+xfX23YSdFuvyY2lmj5j2Jb\u002fwnbeue10o2NSWObmb90YMdfiWBqKkpOmg2KQrKJzpett4R3kMh3Iujzb\u002fFuIKOf4XXYqHGNjzAZWvyhK2NHaeVj+nLGUfabzUn4JDP3r4nbu2vy8+FB\u002fiL0kpzci9+eJJXw\u002f5dg3g0m2pRZBr3Gdb9RXr01ku7siq+xkiy16AZeilLSZlP7tfbk7g9Xj1vQ51jlb4DXWTQ\u002fe2GOb7W\u002fBJf\u002ffRwxPVA5de7veH92KW18KIFvmK6TwGmgPin9m2Xy1fwXMSVh3139+ma2Nz6m1s35i8Iso3cce5W4DGL3L\u002fXxOj5SXm5St0FrVl92ftQAO3gJhi5nl0DIB5i0Vw9+HI\u002f\u002fxclW5O4plBIaNSJdr3vgaXnjfSD8517jH5zKh5E2G1vNHCsXD+vL5+Z55dED5e++hv7VIoivnAwjmZ9eRJ70ym+Wn0Buyw\u002fyW73vffPTz+PzstM8KYObobvqbBIrXU0wlfn868BZfbH1u87e5dv\u002fArx6VBt+l7mPrSHGwW8hfBlfzaa+eq5ll68lWhDJ22uDl+Xkyg2S94N91GAcqjX8NW7\u002fgAWGoTDUwZOr0fqBVlqJSIle9pPw413ZuOATpJT68RQeJa3+KVtNADs08j+j2uHQpGn0p\u002ffq9i82jbtqhGC+7DllqCOhtKtaDpaPLPubN8rco5\u002fw47+DR\u002f5sgv9oJgIRQc1LkwFh7\u002fbo16ydV7xXaUl7\u002fIf0rd9EZIiPACQbGnWzsj0JoXRoVpv+xR7zn3in6cGHre81pX\u002fi5TrCYtvQbgHZp6lWuJ1Z+AiXq0vTclE4oJFd1rSeSj3wHgA85yu1aKTaw47SBzYQ+741S+DeJ3ouORwx0YX6EmD2mub+lrQtItI9v\u002fo6WgeOyxNycvHI\u002f70GJoJ\u002fASH\u002fIMUCnfn\u002fb4X+u83V0+yvyyEVP9xNuvtnbGVsuPcdq76eKJ\u002fTVqBp9Im4EY785\u002fEZ+J\u002f9Z\u002f9+1o6VU\u002fNDFGkH4bz0Nc3w415RyEp9U7+d4uwFNvRZs3AcPUMVEb5YXbkzHLhJ2jVHWbk6p2upaWLMdF0hVzgWXt29fM+LtDto16c93CYiJKhbbp9C1oOwdgGOAnkeu78F\u002fMoGubqHZMYwyrRV3cXAVQGggPhyt\u002f2LXM6bWFh6HI0ISJti+nIvnel1wdDSAOqFfy8gPodMjB1pXKAS7v0z9heYHeVCKVIdDjwDJVLrGa\u002fWg5Yw4eWwno29MxSvwrECzD+1j1enq1ixq\u002flco+0vR5nria4KaC5LMl1yjJsYPHZwWfYFBouYkqrCJOrh277\\u002fJRho7LKBuVhlSMs1anKFYoDUt87Zu+C7yZA4UBR5BscvycWeqJMaIW1Z8hWYeZhDPr+xkmHLofpoIj\u002f7OpzZEoPnZ+1MyUbxWLrdbcaToB8kYINjKcNSA5sO5pk+d54k1KFYwZcXSpshCMXxoKy\u002f2Q+OGSlJrRCMBA7bKkdAY8\u002fh1KXG8styiEicE543Py+ywIXLAcvhXG0BwuWJeYzFyEEIxUfgCjdtdxyC5KMIaaKBZ9H46lBTWaYLAhkcnNW7QhaFBQ6TM5NC0zv2elF8BwzEKXKrAjwV8U2SmTRHCByYhAAC+mJ9Bl1F7\u002fryFQiT0i7Cn0\u002fVZfr+wWLhycqigmXNC9gUgjsZ90r0ZYSNg+3RYMkX2rvVvDjXb2zK9o+rGhl0V6cbsoXyG5Q8mclui50miYjrclLosiQGk3k4YaU13vQaJ6VttDHdaLlQ0ZGkZSLdpLUK7JwtgCxARUzs0BjhRSeJRl1ogKlRuIZau9yk2+nAfrk9L64vdUYiJKTLRNDwa9MaX+SmMFr0K0MJKiEJBjluuXNoNN5b\u002fAqr7gKGAvLUYkF+fwvVjwlyMONe60vzKq9tuMvZtwzXNBmpOxOj4d+ixvKkgkAzl+OlnjvdSeya6W8H5wzAWv1Gwqa0iZcowJVCdAOacvN8pwKGc9Cnszfa2NwKUTyzFNZTUvSeGMPno7zRGlnBZhldFEPXjJs7eg4AgolUKzUSzQGZAHcVOPQ4pIUnN8gcr4nI8mVxKZ36IVxMum55zj8UFMAEGp9PLcu\u002fudZTfDFskF1\u002fyPjAtXucSmzUKeCIbAwDCuTPxiAiIESlmjQcsMkhk3VLzDMPbkp0FwhJSVhhyowyn7RFVHlvw7vjpUIX1zGjMEMQTaLdpBGN0DAS7cB1Gp7+xP4VeZbObpqHlKWFWMnRDSD1zEI7diTZ1cD5PmRawHgQJiKh+H1hQkvT0YwtPqGy+Yw5GSeTOqrmNy+1PjEIZu\u002f4epdLzXrAhj\u002f ...
# Step 4 [total time 97.3s]: 0.3 Msamples/s (6.0M samples in 19.388s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="469c442c-8745-4dd1-b063-e6764f62f36e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("469c442c-8745-4dd1-b063-e6764f62f36e")) {                    Plotly.newPlot(                        "469c442c-8745-4dd1-b063-e6764f62f36e",                        [{"name":"0","source":"...\u002ff39\u002fv9\u002fe5s7vc+cOXN6PyffB\u002f4H\u002f8n\u002fLXdnVk64J\u002f+Q3Hn36JtL5PH+dhsZl7lZ6n\u002fe6NxtHJnub23u5t62Xo6h\u002fh5Ua7uaJzHrw9jgbpdkGNwCHOcVo\u002fyQxD4TM01dfm\u002fjHDp5ALwF0vtki7mgO73ux59snX7TRfQZ+o7qG2s\u002fpdT\u002f5N\u002fVwPdfvxzGE+5sbxUOGscvB3ejNUMr3Q3NYfHtySlVXVmf+eDkWr0Xt7RtfSzWbvXkl1XOUc+rXspf4G\u002fceWwklHL4MoAeJrz5RTrCfWPDG1di651FePFuPKoJmaxtGcfd5q5r9ycrftAF7LD9W\u002fBWreFf\u002fujXS\u002faH\u002f8pL77S10Wqw+jz4mor87nK7NMz9kxVi97r7bzPOx6p7ejRZqaxq\u002f2tu7X\u002fnzJdbkpdzcTG5bH9145HgVswywhyGXPdKCRqON5\u002f0yvxfTkRe62CTXUa9DQ\u002f8I\u002fxJEQSMs\u002fdpM3zzIx+MnFcGBaoRkJR0vkJFvkgvUs\u002fwyke13JuLX2Xn3E8p8b3YTptSM39EZu4H9daschv1h42zb4r3f3umPoz2nxbSmmRAXWw5oc6Xu4uvuYud95cuTqBuolSAmh8iwulbeJY4\u002fjrzzn+KubIN6o3pb61z\u002f5+Guvr4FD+OzryPXGh8oKf+Kx46Cp\u002fdaNXkZurHg+kHg7OYMFInt3TQbETdJbwORG8dWOQ97I16+CG5vbClyyVvuwXOjYKSumFeKAue4wW7B\u002f1edfNPuzFy5ysytdpt46mT1kx9tff4r9q3\u002fgip\u002f\u002fW3T87iAe0WhbnTe9yB62m\u002fyL\u002fT\u002f4Mn0T+XwyB\u002fCexEPn4NH7XuvK68gvwnuH4LNr5z9MFfrEpMtmd2serd90jlC1+V9SWP\u002fqOXYab89Sffx5Gr+59CjTt2r0U\u002fkPOwefQ1hMPY3QfxX\u002fzUTr8nq6Q3Xexsdg8e3Vk5Q3JieIpYlEcuxp+73vt0e4p9Ai6kZNJrdzaKcUBZunYOgkmFtq4IRlFLf52AZ549vGKiSfkRLvwL2Pqqb28L80d77c6n7wm3JnHcORmnOPBZG1kzZKdQyklU8H5n7gTeV2v+706No\u002fnyXkOR36N1rc3q+dONt8LzJafGu5I+mLf\u002fhl78QlAhBwNyUX52tipzJ+vQEiif9j+9C\u002fx9uXd3+vjZO4Hy\u002f7jKxipydG5s05kx19a6ObmJRH\u002fQFhulfPpLJXh\u002fQ7Ofjka5u5R2qirtaqmkJC\u002foBkVQu3Vpq+T81CysTq5aURg9AujNniUnXGbqqb+XKB9l2rFfl25C8fhR+ElXV7pP45Ufwsyqivw3SeMds2qlv1nxpU7vVvXweLKRb5nekucMi\u002fHCmBYsvb38FotFUv+gMAb\u002fi\u002f\u002fiDzNgpZw3L3VPDKOJ2S\u002fxSG5sZ7Z54wU62CZSOMScTGk2fSr0oOk8FKtbu7MxIkRmWFOYpRZkMzWnQorQBTz1Vf7lD17ct9L+UHjrew4GsAIUzMhQxIL7QWZ25M\u002fYySj2V+6GP1VBVwl8ZE5RTt\...\u002fOWUMW8U7FyDNqMSY8XGtZnssYQFs2c0yJwCMIMkMdkEOZjNGuZJnMS6BEHOr2ql6uIsmGAZ0vawG7DzvrpHC\u002f4ENIcNNCkRi2XFZIyYRDu266Rvb0N\u002feu4uUTZK14lUcfZtIlq1kLOrVjwJWmxsVbw6p6ooLEU9OiFgbl\u002fzQ8wHCiLTTuN9Udlwq3NjCFAgYKOxnMc0tR7hJ9I5nHSsdt\...\u002fCMPvzPezKI1yxLBLTT4MHs33u52RyrjR0SLjQKrIxFftzHr8u7bCG8leMUiVwW\u002fGJ\u002f1AfC\u002fAYkKZt0k1sTtICMwkYx2ozpyp4GoZfFp1Vy+HAJWhhMR+m0Jr8ySMkwOLP1nHc9Ib8gS4UhbLX69Xd\u002fbep\u002fLJmZdXUgn+ytH11jfOwJMOVTNWK1MoMQUJzBCO3INSYs1nIh10NAY1CGsPQTyl4ysP8YgbNBG8IzTcCv2Hp0XtBuFVltPJKqiLYi9M6N\u002fb8Hb8daouRs2VloajPQZbsiI8IsAZpd6hoNnvtT7DzjPBhiERlsnTetMwwuIbJ3ZJClHIAOXjqWBxswmQjIWxfXYUXLszg+Uu8+vrOVEM0zFr1EQqB56cUgDgQVdSEuzhOFxFIUsfakBzpRRZckoZZjsWYX0saedUNr7vPOwwqdzQ92d7+xXZo\u002fnrVnAx252SzPBYdxeD1Njc6NU65bgZhjqR+okHA7tKz7pssvQC5nWVR43JjZhId\u002f3nNFvTE4N6dDvKXX0mWuO3MSUqvP1WOlEAo7IIU+e5YUboPI+Hm5lIqiEueXkEgEsHMBkzq2GKiEfjWmbhgDUQATmJSQvmushCVPT0FFUEPITCHpYsFEwD1hHu3uw1k7759oM3KQceLp4HiPlzPJeztsOY1ekAEzaU\u002fQ5ctl68fVbJDAyfYJC41eOCqN\u002fQYIhf4yOdFdo5VHO5rWST1tL166jfmCoYbOSZIdN0lQDtxjWHLP+mgMEbHLVMu9M+2a1RRZSbmrIuDC9SFSNGKDybnK2F6ViGnvOarrzKuennZIyoLn3UCOZItHu7ntssAOv6uyeuH+XG5k5VTeMAvlK9NDembhRhh2bVCZSSh5Ajqwnyfrx4d0ZqiMwv8lNMKtLz2+ksvdzvf1G4mwSOopM2giXpZH\u002fVrWHYRVhS6GA+9Mo42NueIGGmwfbBXxOw1uVh03sDJeyopgNfJ44NW46LfoDSuP2ThV+aDd7SLk6cII9ofMYnl3yvjO\u002fGzPaomwTdmppNhmmHTc+Hjv5Orr8Kj1ir2nZ6eaf6Wwi0jvPfgKqhZXGv7YxAzB56sbASN2KeO1+prkUoH2+u+M6keiWvxBOkWFemPlXVEWhsvJ2oqeXMmKzjTcXone5jb8Kbqv7a6\u002f7ZIxP807\u002f99xqbs32n9Drl8MMJaex2J+rdW07bn+Ts6EzjrjKtUj9cA8ixqbbgzCqR14iZZ0xv0PAelRVl2REw5Kx3cz+FWDOKCJjNvPoTIkdI5wiZp2Q8IDr+16aynUpFQAM23qexP9NCZoTXQOCK1teKttbW5OSH4\u002fkvy ...
# Step 5 [total time 116.6s]: 0.3 Msamples/s (6.0M samples in 19.355s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e5547f87-a723-4b13-b84d-664b23b54181" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5547f87-a723-4b13-b84d-664b23b54181")) {                    Plotly.newPlot(                        "e5547f87-a723-4b13-b84d-664b23b54181",                        [{"name":"0","source":"...\u002fOufvmfCeHN\u002fPyBmAXYUkQYIGQWAQtkbbKKhf9w3Io+YdM0JbKxaJULjqRLKuIDBDYgI0vz5t5k+fOzalv5xxOn5zP8feB\u002f+vf\u002f9eZ7zVvMuIXj6MPSic\u002fPpv9xr1396yDRQKLHi3PU4fHtvzRyv3MfLr3K0h+MCsMbMgn3OWBOLjWIxQatyI3ertAfzxXHst8F+Dv3DoHPr8BHEWJCtlPXeKdvnbzNtI80ImGCX5fJ63F\u002f4mc\u002fJc\u002fWb728PjZKAWEw00UIoLTb4aLQjmFxnIyNCoenh5TpXtLs36ncxXckxjjnjWql3d0bRBnpvKFD8UT5\u002fghMV+1+FQC49Po8djvQMl18\u002fkI5BTXk9rQZImvsgKStAjr\u002fKS5TrsDYzeAzoCreOcjbXXtYjz59SNqvPQ\u002f4uvfGWjj0qD82v+72NIflIeL7cy\u002fr06LV\u002frfLKC\u002fMwjOTybV1ILxh8by\u002fyVWi\u002fVlKcFNa1s79K\u002fOoADFBQeDkJg8n95Kyp5kvbTz7D13+TQ+quEV0V+eD\u002f8CGlRRX7m4J1iTg38iQNpFAclJr8MePNc4kj9NKomfJzZ+4HGn0WfxDvcfgsHHhV9XyQvsrzDpTlxvn1NrUKx2cn7B7n5M9DOCOcglHNXUD+Mbi\u002f1RuWc9Y66E+5v9U82Qskt+c5eSzg5hQzr5Kln53Wg9Ak+Rpv+DJfZf7dM7H\u002fyte8HO\u002fH\u002fmQ8efTeP\u002fyySkAm+a58X4h8mfDv3bV8+kzFifbFGO381YGezJnL9\u002fGHkbQMs8\u002fg61WHOMUQG4MQAmBnaaVjMHWoQxUNk7V37t9v2\u002fuhDo3ZdcNtXrBLHTnmK83lj+TffB347qN2avL2LTLLp+p+e9uG6AJ1j0IXv7s+\u002f\u002fqPQZE\u002fGpmryJr72gptOdl8Vz1HuUMLcujIfKO58vKHrKw7vK8vsfAtM\u002fp95g6gPf\u002f3+8Ya\u002fzzz78TRxsXPti2tzh+21qVcvrk8ctLgHHrl1HP\u002fkVU7rTeEOOSPdB8Wp2fydxSlJnzqA8cb3EeedLDnqH78nsfWhkSnGl076Wq3J68IXb4y+yKvWkSAlG\u002freK4clllO\u002fTULyzTMB\u002fEyOeyuBtb7qyOn7z6Y2l3aM4lnpaT+TYH53CO\u002fCcXiymp\u002fTg19qRpsOf7oYfT01Vq5YbWvu2YhpjQ988XztcesXapVLYt44HnX+azj8BdWjoAjtIYqjkNWW6VaRt9XzwpzeA\u002f+MU2p1lX13va3\u002fpJrSysThQ16j8kOs6rRTTQvjvd5STfCB8g6fuZTruk0lz6yE\u002f\u002f9zqMKU8qyffkkMcTyw1nmzk+Z9YN65PH18JMHIMUKuAqToCMAXdf+xXn6X2uEeZyxA7ux09fGZq0I+ktX8cAVQc+WN7dtsWnMRxNWh19e8Wnx1P169P9KcpPjskuOyY5x1l\u002f\u002f5hOpDE\u002f+m6DP7Rv\u002fqvRVC8LYRPTX8OCpz8GcVlT9zUt3D10fJsx8kDMHxaB5ml49IJejZX5O33FuoTIcf1ncNyWFXMFqOTCZYYxnD6i+jNrw3fnSesEXGQZPyGhVXgCCSIDmpc81PzM7XBuB3p1++0fmpIoeojrBMEgCo7BOqlSxIVh5ID7SAkJo4DsiMpXZZqMBpOg7D6DIriUkeaUTdC4rENUWAfjTN9pL5Ri33JcyUxVvKU6XBQ4yrJPJ2pj4FlSX\u002fdn9HSkvuqn13bCKjHaodSUtKyYWpIdzq\u002fzaaeuI4RgLFMXsQj3\u002fNVf8gjnqaDUCxrTjsuJSIzKEHRr2unZBEHAg5hoUorPFjGVyeGiUmu0mSITY\u002ft\u002flDFP8wNiQs9wJKhEUQoyy80C7JrzNiTOGdbmbJsTUo47V6hM1dnk1NsJdE+wxbnExlMcvzxzFiN2dNZYRrXr32THNw5ODc2rrk9kOKsuS0h2KyN2\u002fHZEEOXKZ1NJ48uokz6Mt7yLwolCbBDA\u002fCHmJeEgFGDLaVHLBeFaDKlDKdm2cKxvqabEIOCfliF4hbWnGuVrpUqtw4gsERwBPbhSfBzsb8EUqNugCxn3bmBxeZEXORm866CE2NgpC\u002fhxmQjUC9IMqgm9MFpweebMSOjiB1B2ZI1ncHIUDjiQvTMhFA0zfg2CI+EJUJ\u002fkcOBWkxk+41VbmXSHypihppB8xYxW55uLSXtEWxe1pGYydsFywRsxiChuQ6WbieJv2j62QwgwmcEJShHWTrvB82DLlimdYq5IQ\u002f3ggzP9wUXi8dyRn8KK47KZz16LmBjWVsB+AkwGYOcaKC5FRN5a9UIVcovJNCoM20QnKHKaQkfFOtrj9N4UryMcNjuVsHoosVC7ySpYVdAygfKfp5DWktMrOZX00a9q\u002fAoLuALc88lcANlgplOhwSYiCUA\u002fLLtMYHKc5Eh2WmFUp0+yKY8AOhGt3aJZ+fQagJsTkZACAhU6gBzljLz1hl2N8YfzGdpf5khOpBXkrdPW1PXts0dglaPFShRLNLOEIfOYXh7IneDIkKcl5JLwjQ8wWFndMHQkTSpvqDmK7EEvzhtNGzg0J5XKVGTMiH4PBekB6rEeZDEmP2LYWwBmNurh\u002fDkuuz3imRlLhiSLY79TjIqRGjnTA1TggdlExYxjF9B7BmqX8\u002fryuhS6++EUba6fdhrIXAyxRGK3em0Y2u5McyUbeANCIVSujTvt52u1Z7kyb9F1\u002fOqFMYR8syh76ZjwRxNvZyvqEGpJhD6HeTa4g8GvhWS9XDkk9SfmPiOspVK01MSN3vk7D50a7R53jkMWJjdn4gEYozpGOMyCf7dmSm4CSPbxcvIj2R\u002fEpgPApHBdxZFVCnd7OUR6EpSX87czpyF\u002fTx8vmKt6w042MIwYvM5jSycxCGXbJuxg5ScNl+AOrsPjrOvb6e2kvfQIi77rGpllwxjYvUfd888Y6\u002ffEKp5BMFl0JMs\u002fsf6fi6\u002fbrLCPnB+5UMgqp1ieJyWFjfxsueMFfR8oRmn+Y9Os7URXeozqTBbCSJyZuAxc3k9ucMtxa+82DR3HIkLF5SfkrMcDHLJrnoVGI3fbf2Nvb9G7EycrCPH074Bzfr5H5q5C6wkwAg2vBwyY6o5jYiCLyYBZd40RiabPE9dW0+ZDTJdGIY6kn4r1x ...
# Step 6 [total time 136.0s]: 0.3 Msamples/s (6.0M samples in 19.352s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="23bb16bf-6cfa-42a5-8bc3-960d73302ff2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23bb16bf-6cfa-42a5-8bc3-960d73302ff2")) {                    Plotly.newPlot(                        "23bb16bf-6cfa-42a5-8bc3-960d73302ff2",                        [{"name":"0","source":"...\u002fvXvqenx88aYIEBQLjDgWdI6WiCZNBJ+kEqRClClA3+IBVBUhfBOAZxBx0IYIHdxS7WzI6f9ub18\u002fVMeV9ZlZXeZ+r7wH\u002f2+\u002f\u002fX9Hd7O7T45Fn44Xb\u002fr14cfHL7t487Z3fW6OlZKQxOX7eU3\u002fr+XdwbH\u002f2lvrjn5ecTyOaGGeiBtPzGVoltEFKt7jKyv7CfjslzKPZx+jqc7AFdYAkj6rEGro65jVth76CFnlngHxue\u002feB\u002fFbv\u002f6EfJnbfqn+opxpjsogoYSG+m6XKxwgnZM+Ny\u002fVp6CRbuZKGx86KtPhQR9J5gNksxYziJA9pYYuiVWDf8NqO8dUVZKQpIoIrsh2giq79qI5ZKxrgDpLNMf5\u002fjp3Gr4l9fDNd8azhdB8Q+0CHGO34t2ZlBD77E7Ld+hK2VmiO7bK63\u002fB8D7L+3BOCt9D+vye80jD+vSL\u002ffEpSOjlXL5u+1l\u002f6bspWdyGTSknsbCerVCCJ5bOpjrMSO8Nb3c1A3D9U1gd92K6\u002fiRxNspxLsvpj8vDjJYIF9VhFw9Ref5DPq6R1k2X7T60uMtUPUDhLXyc+g0m9a6cvk1\u002fGI\u002fXN18p75PXXzAv\u002frglgB7Os2\u002fr4nnHWvO8j2e\u002fjrDO8Axe0mZALfxCuV1+fLAXMuDON3UqeXgO5katRwJ+CeDaFZ9sRMFj6J9iRQ9cevvl+4+c9Pna2Hv2COSy32t0Gv\u002fnoe\u002fx2RUZG\u002f6V99GH8H\u002f5+ns99qPUlkXP2iDLP8KG3lsScku\u002fUZQGyGunF5E6NbITPjrQ2TWMDYt7i2Kc9RIgYi3rX80YPf\u002fPElTa39BZdYl0aIcT0izUNu6fuJ2teSvSS\u002fUUQ9g95Kj6af7Sv5czl8Z\u002fXdr\u002ff\u002fLlUvYBzYRJZx+rVlIu++xl4uqLO3tI2fTu9T935Gm8iyjRtq9fZDUP4b4BgN3sah\u002f+EptpR99RsfYOSLnc\u002fcg801TVqUFlW0+aSXTU4Ku9\u002f3\u002f+ILcqvWMbJnsvtb+bZ8K+G2Kpua03VaXbTqj7\u002fGwDu4ZxSWwYERM+aD6AaQMzig4U3YY0jn2iSXozK\u002fRQDPp0DunDQ2Bjdw+O9EorMICtxkJa4f\u002fnjv5lunMJn57Cy+lv75JVSF1bCaj8sm8hvOtG+kn6fCT3DruVy+1x\u002f0swCM9PrAfme1Xn2jOvjdKGrWJ8Cfktmn7DU8JYFtMhEssqOB\u002fNYuNdOumz98CPxnHehjOf6LcjT9clzUSubaRK3mcnDUb7czTB9m7w1UPyd5zzPCnfSs3ZODtbvc+ZvBOExmGS55Qk4wbH2982fLierPpb3vAM9+KcDxLyLyndDSJB6AQe\u002f3\u002ffKj9cP1X2UvXOzF\u002fuDhCa26n6Z3\u002f4FhEinsXwHwAwVwkOMK92qo\u002fzb\u002fd0Pvd3bn7nGSFqamLQa3k5PWyZ2zFCMKf\u002fb2Avx\u002f\u002fZ\u002f+GeYIO0vhoRdIC4yVn4CZSkcR3w2nJ1vWFhCHAurVxE+mG5kr62hBTFd3Noc9PpvXgWYczRjzK9JDC3BcQnHqPDp4T96XOMchTnCG6FpeBQ4jAp+DRg1eWhyNhgI4i72zrX5qIoCmgowOk7w3UpSIKJdpPOuudKKvMEDXDUKwKVEsdHkXM1yNfuXgyVyDjuJ3A\u002fqVBsacppXi5uIwdx0\u002fAtgMLCyx0rivNFmqUohzXRtJxZTLsczxFfuxkb65FpCfun12ms7sWrMR0pnLbyXEz4HQM6DleBIhfCVAfHXC055mTk1+C3YnYMQCLiYixOPRVTzmAg4Ls96aQn6T4vZmC6uUdus9Ct4NxItfqNyD4pRoGBCcmTsubTHsZjeNu36depmA4HmMcgnwJkkPW6i1mHNlI7acO2wa2bm9cEgu0THsIqvP5XI\u002fZdx9hI3vNMfG9o7dApmErcxzcKw\u002fCIyY28eRdW6O8xvNplYoXwLX4aKQQDXYBULGdlUao0dXQLFkMV4kFJPwyJSNuEUimtxfEKU46Q6XzPiE6PnB0lBniqOubmZTGdy+cUUeEAORYOxeAN\u002fg5B7ECTMmSZGaPZQVWBKVaANvztfxYRunnAo+keTVADgTrYyeUQDnlqlLsRgZOWchjvYcF482eWAQwn2sxhuvCzGzyyHR1L3JlVvSPKLTsOp6Q6aZUz9Yi3WnVvTKw1emmBrXPSKgFQ4aW+DGapz4tGdllrBQPU\\u002fJ66m48ogALxnihJDVom0b4PPabsEyRUMRXhq0D6d5teBlr7WJ\u002frbfXhaYIsBZWEOYsFqEstH5Piq7REJj0skXW4E1538NKcXeWk6GQadbQBLl1bq1gS2UykU15xBb0AU8gYrxB37GoQWQjpnXzvdpvF8tkF+pm1loLS7ARItEN1IitEkwt8oywso2+Hj3nvWbu7fW0BOmG6HE8eHfjhW1uY303SqT+DHKt67Aa2045eD0xBAWGnGpRB7qm2QtsiI73c0ylu3sn2GQ36+kCxfvzvOMeTDEoR2c+\u002faRQHtJOFDZzZUiADKw8MSuGf0OW0VxYP4ISMu9XnISzvD5DmhxCcHCyJ5Khj8V3dK+aDG5HDfI1w9s9IyZlD7Uruw5Rdax6nkQJJcAETM4h5bp4XCukEyfaPeFYAy6T2HyVt+Zn0FEfxgojKNG+18LPrDZmYQVHbmYdJJV3wA7ek4bW1nxbvxnWqbEOXtL5TMlkIGqTFgIUCWHDuXntm8O\u002fxpeLiOrl9Zm0a4knSBSX9a\u002fFULukZjMCBa+jDKzwpvxraT94mCpyvdx1M5Jg5TW6VsNCNTxWEow7nG4qoy6Wv\u002flhWqcf10Fuzl4ppZD7BfbGaBKryyz ...
