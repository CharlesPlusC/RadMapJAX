# %%
import jax.numpy as jnp
from jax import grad, value_and_grad, jit
from jax import random
from jax import lax

from collections import namedtuple

import os
import time

import plotly.express as px
import plotly.graph_objects as go

def normalize(x):
  return x / jnp.linalg.norm(x, axis = -1)[...,jnp.newaxis]

def visualize_rays(positions, directions, length=0.1, max_rays=1000):
    end_points = positions + length * directions

    positions = positions[100:200]
    end_points = end_points[100:200]

    fig = go.Figure()
    for start, end in zip(positions, end_points):
        fig.add_trace(go.Scatter3d(x=[start[0], end[0]],
                                   y=[start[1], end[1]],
                                   z=[start[2], end[2]],
                                   mode='lines',
                                   line=dict(color='blue', width=2)))

    fig.update_layout(title="Ray Visualization",
                      scene=dict(aspectmode='data'),
                      showlegend=False)
    fig.show()

Ray = namedtuple("Ray", "position direction")

def spherical_to_carthesian(spherical):
  x = -jnp.cos(spherical[:,:,0]) * jnp.cos(spherical[:,:,1])
  y = -jnp.cos(spherical[:,:,0]) * jnp.sin(spherical[:,:,1])
  z = -jnp.sin(spherical[:,:,0])
  return jnp.stack((x, y, z), axis = -1)

def grid(shape):
  u = jnp.linspace(0, 1, shape[1])
  v = jnp.linspace(0, 1, shape[0])
  theta, phi = jnp.meshgrid(v, u)
  return jnp.stack((theta, phi)).T

def sphere(shape):
  spherical = grid(shape) * jnp.array([jnp.pi, 2 * jnp.pi]) - jnp.array([-jnp.pi/2, 0])
  return spherical_to_carthesian(spherical)

class Mesh:
  def __init__(self, filename):
    self.vertices = ()
    self.faces = ()
    for line in open(filename, "r"):
      if(line.startswith("v ")):
        values = line.split()
        self.vertices = self.vertices + (tuple(float(x) for x in values[1:4]),)
      if(line.startswith("f ")):
        values = line.split()
        face = ()
        for v in values[1:4]:
          values2 = v.split('/')
          face = face + (int(values2[0]) - 1,)
        self.faces = self.faces + (face,)

    self.vertices = jnp.array(self.vertices)
    self.faces = jnp.array(self.faces)

    box_min = jnp.min(self.vertices, axis = 0)
    box_max = jnp.max(self.vertices, axis = 0)
    box_size = box_max - box_min
    box_center = (box_min + box_max) / 2
    self.vertices = 1 * (self.vertices - box_center) / box_size

    self.build_area_sampling()

  def heron(self, sides):
    semiperimeter = (sides[0] + sides[1] + sides[2])/2
    result = 0
    result += semiperimeter * (semiperimeter - sides[0])
    result += semiperimeter * (semiperimeter - sides[1])
    result += semiperimeter * (semiperimeter - sides[2])
    return jnp.sqrt(result)

  def build_area_sampling(self):
    self.proto_size = 100_000

    vertex0 = self.vertices[self.faces[...,0]]
    vertex1 = self.vertices[self.faces[...,1]]
    vertex2 = self.vertices[self.faces[...,2]]
    sides = jnp.array([vertex0 - vertex1, vertex1 - vertex2, vertex2 - vertex0])
    sides = sides ** 2
    sides = jnp.sum(sides, axis = -1)
    areas = self.heron(sides)
    cummulative_area = jnp.cumsum(areas)
    pdf = cummulative_area / cummulative_area[-1]

    proto = jnp.linspace(0, 1, self.proto_size)
    self.proto_indices = jnp.searchsorted(pdf, proto)

  def get_normal(self, face):
    vertex0 = self.vertices[face[...,0]]
    vertex1 = self.vertices[face[...,1]]
    vertex2 = self.vertices[face[...,2]]
    v0v1 = vertex1 - vertex0
    v0v2 = vertex2 - vertex0
    return jnp.cross(v0v1, v0v2)

  def intersect(self, rays, t_min, t_max):

    def intersect_tri(face, best_ts, best_normals):
      vertex0 = self.vertices[face[0]]
      vertex1 = self.vertices[face[1]]
      vertex2 = self.vertices[face[2]]

      v0v1 = vertex1 - vertex0
      v0v2 = vertex2 - vertex0

      plane_normal = jnp.cross(v0v1, v0v2)

      plane_d = -jnp.sum(vertex0 * plane_normal, axis = -1)

      normal_dot_origin = jnp.sum(rays.position * plane_normal, axis = -1) + plane_d
      normal_dot_direction = jnp.sum(rays.direction * plane_normal, axis = -1)
      tri_ts = -normal_dot_origin / normal_dot_direction

      hit = rays.position + tri_ts[...,jnp.newaxis] * rays.direction

      edge0 = vertex1 - vertex0;
      edge1 = vertex2 - vertex1;
      edge2 = vertex0 - vertex2;
      vp0 = hit - vertex0;
      vp1 = hit - vertex1;
      vp2 = hit - vertex2;
      c0 = jnp.cross(edge0, vp0)
      c1 = jnp.cross(edge1, vp1)
      c2 = jnp.cross(edge2, vp2)
      f0 = jnp.sum(c0 * plane_normal, axis = -1)
      f1 = jnp.sum(c1 * plane_normal, axis = -1)
      f2 = jnp.sum(c2 * plane_normal, axis = -1)
      tri_ts = jnp.where(f0 > 0, tri_ts, float('nan'))
      tri_ts = jnp.where(f1 > 0, tri_ts, float('nan'))
      tri_ts = jnp.where(f2 > 0, tri_ts, float('nan'))

      skip = (jnp.isnan(tri_ts)) | (tri_ts > best_ts) | (tri_ts < t_min)
      best_ts = jnp.where(skip, best_ts, tri_ts)
      best_normals = jnp.where(skip[...,jnp.newaxis], best_normals, plane_normal)
      return best_ts, best_normals

    def intersect_for_i(index, state):
      best_ts = state[0]
      best_normals = state[1]
      state = intersect_tri(self.faces[index], best_ts, best_normals)
      return state

    best_ts = jnp.full(rays.position.shape[:-1], float('nan'))
    best_normals = jnp.zeros_like(rays.position)

    startTime = time.time()
    state = (best_ts, best_normals)
    state = lax.fori_loop(0, self.faces.shape[0], intersect_for_i, state)
    time_taken = time.time() - startTime

    ray_count = (rays.position.size / rays.position.shape[-1]) / (1000 * 1000)
    intersection_count = self.faces.shape[0] * ray_count
    rays_per_second = intersection_count / time_taken
    #print("{:0.1f} Mrays/s ({:0.1f}M rays in {:0.3f}s)".format(rays_per_second, intersection_count, time_taken))

    return state

class Log:

  def flatten(self, vertices):
    vertices = jnp.reshape(vertices, (-1, vertices.shape[2]))
    return vertices

  def init(self, vertices):
    vertices = self.flatten(vertices)
    self.path = jnp.empty((0,) + (vertices.shape[0],) + (vertices.shape[-1],))

  def add(self, new_vertices):
    new_vertices = self.flatten(new_vertices)
    self.path = jnp.append(self.path, new_vertices[jnp.newaxis,...], axis = 0)

  def plot(self):
    depths = jnp.arange(0, self.path.shape[0])
    depths = jnp.repeat(depths, self.path.shape[1])
    index = jnp.arange(0, self.path.shape[1])
    index = jnp.tile(index, self.path.shape[0])

    flat = jnp.reshape(self.path, (-1, self.path.shape[2]))

    data_frame = {
      "x": flat[:,0],
      "y": flat[:,1],
      "z": flat[:,2],
      "depth": depths,
      "index": index
    }

    scene = dict(
      aspectratio = dict(x = 1, y = 1, z = 1),
      aspectmode = "manual",
      xaxis = dict(range=[-1,1]),
      yaxis = dict(range=[-1,1]),
      zaxis = dict(range=[-1,1]),
    )

    fig1 = px.scatter_3d(data_frame, x = "x", y = "y", z = "z", color = "depth")
    fig1.update_layout(scene=scene)
    fig2 = px.line_3d(data_frame, x = "x", y = "y", z = "z", color = "index")
    fig2.update_layout(scene=scene)

    fig3 = go.Figure(data=fig1.data + fig2.data)
    fig3.show()

class NullLog(Log):
  def init(self, vertices):
    pass

  def add(self, new_vertices):
    pass

  def plot(self):
    pass

class World:

  def __init__(self):
    self.position_key = random.PRNGKey(0)
    self.index_key = random.PRNGKey(1)
    self.direction_key = random.PRNGKey(2)
    self.mesh = Mesh("GPS2F_v6_full.obj")
    #self.mesh = Mesh("box.obj")
    self.light_position = jnp.array([0.9, -0.3, 0.4])

  def sample_directions(self, shape):
    self.direction_key, subkey = random.split(self.direction_key)
    return normalize(2 * random.uniform(subkey, (shape[0], 3)) - 1)

  def sample_camera(self, sample_shape):
    a = 2 * grid(sample_shape) - jnp.array([1,1])
    b = -5 * jnp.ones(sample_shape)
    positions = jnp.concatenate((a, b[...,jnp.newaxis]), axis = -1)
    directions = jnp.ones_like(positions) * jnp.array([0,0,1])
    return Ray(positions, directions)

  def sample_light(self, sample_shape):
    self.position_key, subkey = random.split(self.position_key)
    xi = random.uniform(subkey, sample_shape + (3+3,))
    directions = normalize(sphere(sample_shape) + 0 * xi[...,0:3])
    positions = 0.01 * (xi[...,3:] - 0.5) - 3 * directions
    # visualize_rays(positions, directions)
    return Ray(positions, directions)

  def sample_surface(self, sample_shape):
      self.index_key, subkey = random.split(self.index_key)
      xi = random.uniform(subkey, sample_shape + (3,))

      face_indices = self.mesh.proto_indices[jnp.array(xi[...,0] * self.mesh.proto_size, dtype = int)]

      sampled_faces = self.mesh.faces[face_indices]
      sampled_vertex0 = self.mesh.vertices[sampled_faces[...,0]]
      sampled_vertex1 = self.mesh.vertices[sampled_faces[...,1]]
      sampled_vertex2 = self.mesh.vertices[sampled_faces[...,2]]

      edge0 = sampled_vertex1 - sampled_vertex0
      edge1 = sampled_vertex2 - sampled_vertex0

      bounded_xi = jnp.where(xi[...,1,jnp.newaxis] + xi[...,2,jnp.newaxis] < 1, xi, 1 - xi)
      positions = sampled_vertex0 + bounded_xi[...,1,jnp.newaxis] * edge0 + bounded_xi[...,2,jnp.newaxis] * edge1
      directions = sphere(sample_shape)
      normals = normalize(jnp.cross(edge0, edge1))

      return Ray(positions, directions), normals

  def intersect(self, rays, t_min = 0.1, t_max = 100):
    ts, normals = self.mesh.intersect(rays, t_min, t_max)
    return ts, normalize(normals)

def ray_to_force(incoming_direction, outgoing_direction, normal, specular=1.0, reflectivity=1.0, normal_only=False):
    speed_of_light = 1

    if normal_only:
        magnitude = jnp.linalg.norm(incoming_direction, axis=-1)
        magnitude_reshaped = magnitude[..., jnp.newaxis]
        force = magnitude_reshaped * normal / speed_of_light
        return force

    if not 0 <= specular <= 1 or not 0 <= reflectivity <= 1:
        raise ValueError("Specular and reflectivity values must be between 0 and 1")

    diffuse = 1 - specular

    specular_force = (incoming_direction + reflectivity*(outgoing_direction)) * specular
    diffuse_force = (incoming_direction + reflectivity*(1.0 / 3.0 * normal)) * diffuse

    total_force = (specular_force + diffuse_force) / speed_of_light

    return total_force

def reflect(d, n):
  return normalize(d - 2 * jnp.sum(normalize(d) * normalize(n), axis = -1)[...,jnp.newaxis] * n)

def estimate_backward(sample_shape, world, number_of_bounces, log, ray_config):

  rays, normals = world.sample_surface(sample_shape)

  log.init(rays.position)
  log.add(rays.position)

  incoming_direction = rays.direction
  outgoing_direction = reflect(rays.direction, normals)
  force = ray_to_force(incoming_direction, outgoing_direction, normals, **force_config)

  for bounce_index in range(0, number_of_bounces):
    best_ts, best_normals = world.intersect(rays)

    new_position = rays.position + best_ts[...,jnp.newaxis] * rays.direction
    new_direction = reflect(rays.direction, -best_normals)
    rays = Ray(new_position, new_direction)

    log.add(rays.position)

  is_back = jnp.sum(jnp.nan_to_num(normalize(incoming_direction), 0) * normals, axis = -1) > 0
  is_hit = jnp.any(jnp.isnan(rays.position), axis = -1)
  force = jnp.where(jnp.logical_or(is_hit, is_back)[...,jnp.newaxis], force, 0)

  log.plot()

  return force

def estimate_forward(sample_shape, world, number_of_bounces, log):

  rays = world.sample_light(sample_shape)

  log.init(rays.position)
  log.add(rays.position)

  for bounce_index in range(0, number_of_bounces):
    best_ts, best_normals = world.intersect(rays)
    rays = Ray(rays.position + best_ts[...,jnp.newaxis] * rays.direction, rays.direction)
    log.add(rays.position)
    rays = Ray(rays.position, normalize(reflect(normalize(rays.direction), -normalize(best_normals))))

  log.plot()

  #radiance = jnp.where(jnp.any(jnp.isnan(rays.direction), axis = -1)[...,jnp.newaxis], 0, rays.direction)
  #radiance = rays.direction
  #radiance = jnp.nan_to_num(rays.direction, 0)
  radiance = jnp.nan_to_num(best_normals, 0)

  return radiance

def reconstruct(radiance):
  return radiance

world = World()

# def downsample(image):
#   result = 0
#   result += jnp.roll(image, (0, 0), axis=(0,1))
#   result += jnp.roll(image, (1, 0), axis=(0,1))
#   result += jnp.roll(image, (0, 1), axis=(0,1))
#   result += jnp.roll(image, (1, 1), axis=(0,1))
#   result = result[::2,::2]
#   return result / 4

def downsample(image):
    from scipy.ndimage import zoom
    # Calculate the necessary zoom factors for each dimension
    height, width, _ = image.shape
    zoom_factor = (181 / height, 361 / width, 1)

    # Resize the image using the zoom factor
    resized_image = zoom(image, zoom_factor, order=1)  # Using bilinear interpolation (order=1)

    return resized_image

def calculate_rms_difference(image1, image2):
    # Ensure the images have the same shape
    if image1.shape != image2.shape:
        print(f"image shape 1{image1.shape};image shape 2{image2.shape} ")
        raise ValueError("Images must have the same shape for RMS calculation.")

    # Calculate the squared difference
    diff_squared = jnp.square(image1 - image2)

    # Calculate the mean of the squared differences
    mean_diff_squared = jnp.mean(diff_squared)

    # Return the square root of the mean
    return jnp.sqrt(mean_diff_squared)

def load_and_display_jnp_file(file_path):
    # Load the JNP file
    rgb_array = jnp.load(file_path)

    flipped_image = rgb_array[::-1, :, :]

    # Print the shape of the array
    print(f"Shape of the array: {rgb_array.shape}")

    return flipped_image

solution_shape = (1000, 2000)

def build_force_map(sample_count, estimator, force_config, number_of_bounces=2, profile_interval=1, save_path="/content/images"):
    import matplotlib.pyplot as plt
    import numpy as np
    import os
    import jax.numpy as jnp
    import time

    solution = jnp.zeros(solution_shape + (3,))
    total_time = 0

    if not os.path.exists(save_path):
        os.makedirs(save_path)

    for i in range(0, sample_count):
        startTime = time.time()
        radiance = estimator(solution_shape, world, number_of_bounces, NullLog(), force_config)
        solution = solution + reconstruct(radiance)
        time_taken = time.time() - startTime
        total_time += time_taken

        if i % profile_interval == 0:
          sample_count = (solution.size) / (1000 * 1000)
          samples_per_second = sample_count / time_taken
          print("Step {} [total time {:0.1f}s]: {:0.1f} Msamples/s ({:0.1f}M samples in {:0.3f}s)".format(i, total_time, samples_per_second, sample_count, time_taken))

        def tonemap(radiance):
            return (radiance - radiance.min()) / (radiance.max() - radiance.min())

        image = solution / (i + 1)
        image = downsample(image)
        image = tonemap(image)
        fig = px.imshow(image)
        fig.show()

        # Save the image
        image_np = np.array(image)
        plt.imshow(image_np)
        plt.axis('off')  # Turn off axis
        image_filename = os.path.join(save_path, f"image_{i:04d}.png")
        plt.savefig(image_filename, bbox_inches='tight', pad_inches=0)
        plt.close()

    force_map_filename = "force_map"
    for key, value in force_config.items():
        force_map_filename += f"_{key}{value}"
    force_map_filename += ".npy"
    force_map_full_path = os.path.join(save_path, force_map_filename)

    np.save(force_map_full_path, np.array(solution))
    print(f"Force map saved to {force_map_filename}")



def create_gif_from_images(images_path, gif_path, duration=0.5):
    import imageio
    images = []
    for filename in sorted(os.listdir(images_path)):
        if filename.endswith('.png'):
            img_path = os.path.join(images_path, filename)
            images.append(imageio.imread(img_path))

    imageio.mimsave(gif_path, images, duration=duration, palettesize=256, subrectangles=True)

    print(f"GIF created at {gif_path}")

experiments = [
    {  # Surface Normals
        'specular': 1.0,
        'reflectivity': 0.0,
        'normal_only': True
    },
    {  # Only Specular
        'specular': 1.0,
        'reflectivity': 1.0
    },
    {  # Only Diffuse
        'specular': 0.0,
        'reflectivity': 1.0
    },
    {  # No reflections
        'specular': 0.0,
        'reflectivity': 0.0
    },
    {  # GPS2F Gold MLI Material
        'specular': 0.5,
        'reflectivity': 0.7
    }
]

for force_conf in experiments:
  build_force_map(100, estimate_backward, force_conf)
  print(f"built force map for:"{force_conf**})

# create_gif_from_images('/content/images', '/content/force_map.gif')
# print("Done")
# Out:
# Step 0 [total time 19.4s]: 0.3 Msamples/s (6.0M samples in 19.365s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b42f12f0-7194-400c-9d86-271bb3475c08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b42f12f0-7194-400c-9d86-271bb3475c08")) {                    Plotly.newPlot(                        "b42f12f0-7194-400c-9d86-271bb3475c08",                        [{"name":"0","source":"...\u002fyTncnF6O\u002fTpHoBuhkUFkkCBBUpQpUsGSw8ie8Xhramp3VVszNbVhXJZkeyTLlkiJFEUwAQwgcmx0zunleHM+9+R8\u002fv0++Gd\u002f9mccsymjDw3v2RD9OOgeAdP7Qeoq0PdPmJf2wHfa5vcq+dMZtD5yTnpeTLJiCGSl\u002fH1Q00fYn\u002fD5H9qdPwAA5Jnv1\u002fxXDP6XGes7AIAJ8IM9MgY7IqiEoCAX23HLXgXMvxTCHat9DRzTAS2B1nda4O1isQ5afwzASEi9ZQ2\u002fQyrfDwe1Pv5YpjQCzZdcVGcrV6mG7oyTmVvhKPUdP\u002f4+nbwKIjtP32dh8x58mJv4Atv7DkCxCP5iQ5qk2nslQ\u002fWK37GTbR4VAf6FNdYQagUQPdKTf5q1YwAAh4YOdAB4AEy2wTYAE3GmMdcn9heCnzI4s5sBg45ZmRD9ergbC+PWSSDMSvD7IXpaja818Vcw8L8NwcsGfnc2iBD+lRC8DbzHAfPLIbeESU2l604kYG+4BFKnAAAAALHwc\u002fNuup7tVVItipkYbGhLfLzFdMF2Ucw\u002f4xe\u002fAN22CZ8R0c8BeBSARwB4q84GadmxUFzqvhaaf5sI\u002fwMGLoDxBqh+C5A6aFwri+3GjGi11gX0PxP096N13JKxvhhO4t8pgHf2Wp2o+Bgf50D2v4Phn2rJVZXc73j\u002fBR\u002fP0q0nQPc34FherU1r8Kie\u002fFJuDMBYKsQfR7hD1e6ThZNd5r66tkbMyNuey+NTaTAPQIYK\u002f4+ATAHwJwD73\u002fTo1UPYtb2B1aYLhdxue5jFbDCVPmvjeSPa0YJrKekk50\u002fGzF9QzWIgP5skLkOmPPvv+mHqoHJQiDdqNQ\u002fMt\u002fxscWwTJGF5R74jQnsEXlaipYH0o7T1nU7yVxL2CgtKffhFBj2sghva3vJgTMuPiVT9yWXyo8laBszur9mfSUCTwf\u002foKVeY0XkbfLkHPyU0cKwEusFXCf9nZRzsgTmAH++jv90H2eUOls3QIHxBJP+bCf4UgC8AIPvJrQz2rzvu9\u002fPsd0rx9wPSYhLBAodHY7fN2mkDnCuDR1RpRTNezSSf9yda4F5zMqXeTY4fRNd3wQugeBX43Wx\u002f8ia2VUkdBMOTAMBJ8H0LjK0QtWz0HQDWQPmc03+C834oQ0mv5sHSSWDNdsD7eXAxBP+GzNwH\u002fXOi\u002f3I83HCKlTKoNtyTbfZ+gTo56f5qF3xDlO6n7PsaOmmQY5D8y7x1BEt3NyhAd+sE+L8DgCTw51pNxZlpkH0UKN\u002fnRk844C0gPgPMRR3cMfBr++JHnfAn2aDU4R8GYBZYG5jwT8noZaC8wwdFLi\u002f3tC+PET+rOesZ5hHW22rNMFH19RT8cwP888gZgun7Ptahm98BwExh37sBJfj\u002f+LMJDDxGc0MQqk3\u002fowyVoaJlH\u002fyvkPlk5Nw\u002fTAmj+OCImCHY25LBWaBPiobjHYShjujLEpf2R\u002fN0QiHmnuEfz3tXdsm5PJb2QZoB3S4bZVxgwjEAUnHxn8i+gPwR8h9L828m2KlGJKj2bbKkdAKKj0swbkm4CYiy7ggYVkVpg9OPG96AwecZbsu0j1vq9wT3hQn\u002fwz3pcBZc7Tlf5qO\u002fEdBMFxNFpZ+4WcvjAeNQao9oPRIAJQI3MbYuOgPdfWVc\u002fmgDKXQUg5QrmfMah3JGNBiRbo5hOd8btFnsCSS8KfmHDGpAeVwQBxR+P4j\u002fiHbv+H5oF3cKgqMbE05Es0KEdzMK6Y+gyLvOBr1dkMuY1SKwxKfKQ89jUQlj3y74TxqoigCA5GGMf5PGJ10nD1wHpTQ4eCVCb5FAt6m5KFA4UEswOaQlHueBPWanvh9oB3k0h4NIhzsViJnJFGI8H3yGewkDvtUN\u002fi5HHQ2iGkkyCXrUZc4L3pOI\u002fVz3bjDkszQbW2FPTPZHeCeBkWpfs2ga+Tu08xLPJ7696QiPAfldMw6h\u002fmDM9cuItFwfwMec6B1OUaB5EHGbAr7ZM6wQGDL8qt77kMspvEU6\u002fGMauECThBQeTNAKBsci9Bl0PYI7Gkf7IPF+rHY8\u002faSQHACeAZiCY\u002f8jw7+OyF3bOycyBLAzFjHBgwiOArtgc6zAjxzL5P2x85z+pwhUPUDEVo8IO7R6NrbfxoSzEO2JMFpztktIBf5eAh+E2g1s6ksj9ycBKfHYISRtcN4Lpv93MnYCwNMA7AG4h2OHo+EvfTahTQpmX6ec3\u002fjZXdfOZyzT50+HWBnzGQe\u002fWDSNpng8pnUy0NkhE\u002fCrROBgyqJjAjbLm\u002fY5SXuM4t6xwudZqBLWZ3raYNDvMd7PLf5kyu\u002frMHGDdqowo3Vu8TRGc4o7OgCy17lef6R8LTY6uEpR\u002fjzp1xTv8578CnB3RBpPcNOWyWCA0Tbni5co+1AkGIS7CDMfMf4pP9yLkQ2xr9De7SC8gMQXLXR\u002fHLRs93io3JVhFjqrNbSkOCmUWuF6TEdpcOyTFOUERhcA1Qd0Ub5r6i+PsD0+ug6wEzK67cCXBvS6NApS3C0TnaC8ezbDEtwUb9zQw0cgewCB8wB4oO+RzDSJb2NZZWQd4CAMo\u002f+L5njC+JJJp3B9E+RIybIR0wYJNNBrBLkt9i9hJCjhoBU5V4NwPEe2UaobgkUS71nuWHlMqEXzVnKOst8at\u002ff68ICCQ7YFHfg5AIcwhtT1b+BBVsZucEEGAp7BcUFKO+TbBfjOEJsa802dKgvZX+fhh3j3y1w8j+GvEaAxSL6roe057A42kbO9U64DwtQtFJ8G0YxsVxXWA\u002fCEOqi40YUxaS1GrGkfwp1VXsL8+gd76Hcwc0bXX4XoL23wOg0DBeNMfWh6pyF+EfiPYPckF\u002fu0RXxcFDaA+2UB5DG2UI1fz2BzCXwGG21txs14NDNADFjaUJhdMDzBqJPJ1E9gcpr37gP70YCq+HA+CP8gRk6Yvw+X1jjvFZMoYtiCm5iJftCm2QFcMGBgs4dK+IvQvmOjQwG9BpMyjgUsLLHe6QF8ExdmE\u002fhYN1wWbd4ZtiNeB+hR1z4MgIGpYzE+SSl3RDiOE0OCLevuNnLaAGB9jVS7yxq4jdHfU+D+vgyi7vuCN+K9FxnwLd58E2P3ZcAORTyeZoah\u002fmHerwZwpLk35OiPOAbF+pTgFmPwE8I+qAe+jr5l+sdq8T6vFI6S4y77a ...
# Step 1 [total time 39.2s]: 0.3 Msamples/s (6.0M samples in 19.824s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5c05b67a-ec64-4fe7-a299-006f3f1407e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c05b67a-ec64-4fe7-a299-006f3f1407e9")) {                    Plotly.newPlot(                        "5c05b67a-ec64-4fe7-a299-006f3f1407e9",                        [{"name":"0","source":"...\u002f4wr4QVgYWsC9sA74wYBtYGLAF2NjVUlSkRA7DcMjpno7T6YQ++dSpXPXn\u002f8vhjX4e+L\u002f9Z\u002f+o1YGe8UExugTpp03xY9rqcfcvQHUrGj+Lo\u002f+6aL5odbJBM5kt1jIrNes16Q\u002f65i9Y3YnhH3je3+rlzoQudpy74\u002fIfKvgnbfhWokAIIMOHZNmknRkgb69WR6cAAn\u002fdWK6y41+AqzQgrM4uJeCJ7d+miiyLuh1lDPTcZlxUn9d8p9eCy+KPLPilVqfA8XhvsfpMVfbrC\u002fk3LfluCq56+F8R+PoElN3wKSzuJOKGJv+PotisUb3SMOH9w1LNHbgO7C8m5tP+aDs1owZ+Y2vloTu0eMTdI8N8h9khWL5Mo2J1cSeXWWR+7sGt1F2O2UpgrxB2d1y+1m2OWO9iMHkmo\u002fNFcRfg\u002fxKG\u002f7d09n1lwraEIAQyxUDsg9ZpUr1FB986pzcirRt9gsF6bhSAc1OcNM27svdbbGHMr1eLukfVOPqIHn3P9Dpi5S7JT8rl+4YxSegs4B0T0lnrjLJTUTtUXFf5Vyx4NyrraPAs5j8Axhzsg8BL0tYRyw8q+PdsdGLMVpgFWf8rL\u002f0DH+wfzB8Mune4BxA+UmBDL19A\u002fPe48SeoJkC9p6pH9PLYPrpyBrGtbTNNjPBR7V3VlcDpDKvtabvo8KeQby+LY+qYK\u002fRCCil2vpLZBQPfZPBes6gH8DQO+rkgnlvl\u002fIgUMGhtN8JiclHLS20T8GWjN56Zo51UNkZYkmWrtH87063z\u002flV3\u002fCwGPdD\u002fSlhra3OewXdj9QvDrOr694NGjVZP2uhSnJxE8Cp15yzLIXonqv8iblYa69deD7nJ9\u002fcx2IgfLbpvV2yq6q8i65qwLpLRn8betdyYBJN0OLQK+YfI+DAYTePhVV2\u002fUoE\u002fXsnVSBY9OyyKW2ZUMvAmZHc9uhiBkUO24xpE9Mag+lPssFNpWOinxPjzBRnWo9Mg+Ad29xdkfFMhVgSGnn\u002fast4Z62IgvzxBt60g9PhdngULMhqEW2fJ+lD3bXhSOkcLyh35GsijIvhTY7ZGDSMCcQxqYPwUWJM8feRR4op+YUNQ\u002fTIUf68sER\u002fk6+XJMXhjwT\u002fuWT9eEb85AT8PzG+Rc7cq32rEeYj\u002fP5bRofJSjX9bZzsI\u002fU6EvqnUcyNjTe2xnXXc1IjdtMH\u002fmJrvgmaZ2A1onvXqn3H83FXD3DkE\u002fA8B+ySlXwXNG8DiUj8NBu1i0g6DNBFjJ\u002fG8Mp31L+hx24peNOpnSkoQ7Pnkm8X4jikaU3\u002fzuGPC\u002f+6fdU3yQ8N6UtF2wWJLFRh7Um7Yxumyaq9bhwWmlbqDrFM7ntTAQr4tqkwbHcDOAuJzITXvQHrA7chcWokbuwjy6gq0ci4kVlOo39Q8Aa0xlce8PNb1D2y75DASsKFiV1moUUulbhnGUw\u002fYWMkYXjXKWPnHVLcFrzDraJrX9YB1ZqA6v8WeTsO2zXcLsE3FScijMWlssqZhwioDkqXr6KY8j2kNqifKXEXsqEavR\u002faLuZ66zRAaU9LcSVXmIbBkCDld133cZLThl0zzkOqs1C2MoAaEqmeK\u002fxcW\u002fHpZC+Jl1MrrauiKRpiGYtpVJIaNycPcvCtpuwUSyUxIelXZIvQAOjOv\u002fFnDj3Rnryl2bFoAiJloI\u002fWMmTjS60W9JLSu9Rq25zjZYOQugm8Z9BCU36mc\u002fwHJW5D3LOOk4E6gfKCqkoYaTBQ8M92V2ex+SG\u002fi6pA7PaqHgu4pdhnSh0AsiXEFw24BDi1LgnpVqaLNTyoiZvJZW\u002f6+dp8by3lj\u002f8ww\u002fyTXN1LGbDNsi36jPwPyVcA\u002f1u53UbPOrEcueMH5tKZ9U66wxMbozMI7KQlq8yFShs8GDMV201PGEyCksrYE5xROapuD5rJb+crCCKwW8l9xfEmhBS1e+t41zWQO2wQKa8nKUGDHcpK4oia2DqzkUoYbjM8DdaIaFvjbeX7XMbslnlFsZ2nTc9ya\u002fZY1bynjJXVeydhzrKEwXN\u002fqoWaY6c9tAE32tqBxSR4G8k1WPzQso0rGPLzUqpsyHEPlulUkkcmIkqxBWnjSXlKHmUUIJMxXJD5F6hR7q02yoK3bLP47AxJsJFi+plVW8+cVUpbxJlKHwLro5EltFlwObCuRVUKMmcIeLvuidYqTcGGv2DVDpuUQySts0cNS7FC1j8htgT7HgaHSFVKPS1QhcAkbaSMCanMMnLL5xtYDgX5I+SOMHjf4RqNUCJ\u002fXYgtaL13Yk5zWcIqa2rRr2GxX9FSRtz084dWjprks7E3D+o9G\u002fSMGC6UONL7pi19X6OIc06gxbFprkNMmr10bK4csH1feVYB8yncbv2MuIcPXLP0YhUZaX7ONlyj9VJtDsWyB3gWR70F\u002fx+KlgX5b6EiC30H4hZ8dI2T+BKMFRIWulCvvwk6q+CZWy7ReH6w9LcQOx2cked5RL7W8ZqEdu1nYfAbLO8JbJM2PHGZTqLAZgPwqIdQBF1nT8vVS8KkvIwm+6\u002fb\u002fzLbnrgKiXoHwDUj9GtwU9aEPqtoLtPxBIy4T9yGgt0RtRJzZKhdGZVbbdRVZYA1EJvM6WK8PyLGafjyNVvSUsfJnQM4N3bHRmYvXSPa1KSwYPdLiJ3wyEni0YC8No8\u002fVLQOmlDag6rfwViXfr+v9iVLKggUKLPoY+181yx8LNbTaZ8IGHVZS4aNAAn6R0Bup\u002fjK15k6XenATFJamKkMTjxlS6xJehmAHmEtfnwuZi5trkD4rkGbOcwLbxBgU8FtILZ3\u002fWKiRYoe80shYluoK4f2mvlCQJlHMb31NipsSjxU8X\u002fFJVRkA8KTq1ckDZn0ORGKp7aKzD+TXtsCGyyz8qlMcOMbtSDXQGUZ4X9SpS1+a0Krrlw27rO0pqEynCXTOSL3GzL0EBIW4nYiubJWyainzx8o5aOgbVa1t1nY1E3yoxR9p3W\u002fIz+X4V0L+llZXK\u002f6iErcZXzd4Xtif6\u002fCQ4ZErf+vVJ6ixsdL67Kk2TYDet\u002fR5mwKjnED4Y1iNDLkiun9dsNPl8l+aBfXVeSQWVvedXK\u002fw0nDgng2v69bHrgqNcpooOofjkF9jDnYaU2KOK2p0t+rkF9RZb+h1A\u002f0U6DdsPeHWNUX ...
# Step 2 [total time 58.5s]: 0.3 Msamples/s (6.0M samples in 19.347s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="301a9344-e8be-46c5-adac-0c22df7e5476" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("301a9344-e8be-46c5-adac-0c22df7e5476")) {                    Plotly.newPlot(                        "301a9344-e8be-46c5-adac-0c22df7e5476",                        [{"name":"0","source":"...\u002f1rbHn+vvfd6keVlZlWW7Cg10A2gjkN3yGmhCjfQDRAUjKFJBDTTp0EgRmkkhhSLkBk1KQVJkQw00UCiUy0r7Xj7vrr\u002f3uO338kvfB\u002f\u002fD\u002f+g\u002fEOM3aVByNYDZ35nqz7KxtPhr7ebieN1O\u002f7m2v4nTW7vm60UTN7mg1UMfnQ6otnoJwGcaP8Hu0zUsdvhVqX4i6f9tYg\u002fawJMOAroKtpNxZe0nU3y+BhzEH6G+FGffdDfkmCXrJqdgZQZHRMply4aDAoAfZvptbVaNq9KIMv8j3b1GPKf0WA52R8uNBp829L+IwUdtP8H4adLuyMTzJBg1NXYH+v8aokhqk\u002fqpFn\u002fSsm8S9QOQfFF1j2MwL0FEw3cM3BTh9kD\u002fTuULBH+yJHrQGElOxv5mafYF\u002fXYU9GXSET1q2DCzj8vi44zmdlvmFxc62d7I1xH6FzD5VV\u002fNPJmmvgBJarp3GCSReHUlD8QEsjUAAWRkbd0nK\u002fQqdhXpnTK35fa7BHNkPwvNMsJ5mTzDq4eUL90QJva3ZflHhDzrQh4nRsjdC\u002f44AqnVjDoL5aqMbs70XjL4\u002f7Xufwzwb30dcVaatLOVKOE0Bi6+gmY+MNEy6nY9uOxKO9xjlgdUXXn201C8gOxDR98G\u002fTwJj7S6ivarcDVZYZuEG6HnJH9qyINWv0p1rHvihyvvlswNNa6cgTPyE+mDjr8c9PPebgPuTeOG8FctuifJcCiu1+Q4KzlMiHGf9uEY1DEfjNN2VU3fiM1exwJFWrZRyF728qNJpubrqwXdjcSz3sZDMGu7Wcn\u002fPiEHrR5kNl9tn3K7E9qT2P0RSaz1p7Hc4u79poBt9iQfu2H16IR1k\u002fp8nf4YhDiYv4\u002fpD3zK0fUbJ+janqRqb5LrFbqT+NMovG3ZL2IdlupXSWAmxENWrfrDdJSVdpyaVwKvrpgeuO81eI3N4bz8jR92tbuV4FvE\u002f91GZKpgKLqfZX8Hy586sWLYdI2EmBkkuX3doT+mcSzsUxc216Y\u002f5AcLdX8ermBft1uLvqWcj0D\u002fUCX\u002fWmw+CexyHvw13APke4BWXv5tholzMaa01b+Jwz\u002fXastOriftdyvwzxr3LKefDMnfrvEHsXoL\u002fXtNv2\u002f8Pcb\u002fL8A\u002fwn6nl38Zkjl0v0jKr2F+7a+UdlN6yBUzqPwjDv66BYcAPAOEdu7t2Hy\u002fRyIKWyb83pH\u002fIbDP+\u002fzfDsrPDD2GpubTe315lqaqMV1SJDRMq2kaliWJq9r\u002fUIQNFpmjv3L6Fqt2MH18Ji7hf\u002fqfPKD2k4i\u002f7SjpDaTBUgiB5DDJtDrPo9b7vIe3A37OJDEud7FFyhEea7eOwQ4Ap1BteXpuyTarcTc8j7wwKnd4O\u002fg1ZmfW\u002fBBqTNPX0G+CXHuzH6W6tUNvCMLvKPFdwAGMBN\u002fEBsBQlfgO6Uch+w7bibeCWaREY+UAxq2X6R54f4WHDK0l2fH+dCgnCwgY9RRz0McWIyKaICmMelCDwHa4fanILseoDc+5THyyIurnLThPUdz4AsCERRehP1Aop\u002fAK+sqEm4Ro52KEXgD1FzH6zcIUNPIscOlHcZA+RA6qCLPGN1TftOKbCsgxEUGmCE2VBhQsQtzF4SOjCxWfG72TAOLwW+eOsD\u002fRbCRcanVD6KUJn0H22qgYgucw\u002fAzRTaJvd+xvOz2KyB0OG2MLjIU3fcA3FHwsEIPJoKxfRnhCu7WLYxRuYn9udQYZ8M5yDg3nvd4wGiEVY7CKQtFboUNJwieYS9K968hdlvxadh\u002fqYBgPQ3tQg2+Ju6fsb3j2Y9pvt+R1zIqgawcH0B3ajoLwjrFp76GJFXAd1ROIEdQGp09hs+vFXnC1AZcelcR9nztnWe6BsO7fUDRVPsfgXYQ\u002f9M62ANMQeN81cZty6noQHILxS9b\u002fVCIACOD2vXaDCaVLucE0NaQWLO2rdRZnpn6n4U1IPWa5ci3V105kGDEcbkpwiYOKXKZwLvXvM\u002fh9Y48BR0o1ONrNje3oSwgPKEqADQ7PvDmBYJaYy4pMgThhYUf3MQlnFl1y\u002fj2n1ihGqj3lcEeQy87fQPZEgR4Ci\u002fEdDCpIbhC5Miw4zxjLgn6LKEWkCHrLsWvUxw3mufEKJSNhSoMFZkpzhBz0uXffoHFjy1tDcNVi5+whhStjU5xpDybKNsT3BN0wuoujF8o99KiNXNmbHSiaGAjjUkneEWUoVMhsyQg6OI\u002fxJuhVsCONBpB8y+3dFmsMLGLjRD5VSLRojLSPwhpiGWzmWYJRCpuniu1yAp2tHUZUZ4Ek2BvEzcYdTch3qr\u002fwYKrNMMoSpxpIcxwM9n+Q9gCgTyBfcXmJEJxAvKTwyqnpOHwOM0UAdjzvDUkn72V7C4ATuPk2BdiZuzxKYxuI90Y+cpSufR7rlMMeIOvVLmA2diOlFPVT70rud7T602H6d5y9imFDDbLpFoqj1k6tfxdhgRNK\u002fAPrDzA79uAjaXtmbyWk9fQJkrdq5ahwNpEe70N3JybPjD4t83mQlTc3pC1if5TD5YSMRB8izYn4wtq0r1560LQKZty6cBDQMYOVBouYHyr451phGa4hqjS0NCAal85\u002fYkLOuHUJGJkE2xyQJbS7FMw7+F8ZtpjlLPHfB61DjLZQBtBZ7CVLoNsGtKR4OHGMNLdj\u002fmVJTx3reuIdiTpdBIOQ3EPkhQtfAHUXYwHDNtAY2PuKhlZgkX5N1A8pyCH8eeOviV3rpJDaYfvcRd9CJ3UY2ogH8p4in7ADBD5mteTkZg69ElPgStBDTIIiou2Ojd3dwKWqKZYMug7rm5LVnf2g8\u002fcug0SJaN2qJzc83zj\u002fC+3WNiBkRAFpaj4GYC9hPw7L98p9xfT3UP9M6g9bwoiTa\u002f7XNts06ALTZ1ydIztnwIfNsecRNP+CohSEi6DqWHyIHcM+b\u002fLfaPvCNN8JdQOFHxr3lkWfaLg0xsbqlcDbbfpl5nOgMuMmC7pK3Y9sVjl9GUhwyuL0VtktQjSB+KGAd7y8x7zq\u002fRBENwB5HflpowtERw0tWXuMvdHmJNI6hdtejwNeYTNF\u002fA+WFQnYy\u002fE2h\u002fc7dp\u002fBHWCOlNn0\u002flTbF5g8oOFY8kiAXW5vKmsM+TeamATTAOqIoEiPMfuJMHYNP0nB ...
# Step 3 [total time 77.9s]: 0.3 Msamples/s (6.0M samples in 19.383s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9a2cd753-17f2-476e-9cdc-e608211f4c16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a2cd753-17f2-476e-9cdc-e608211f4c16")) {                    Plotly.newPlot(                        "9a2cd753-17f2-476e-9cdc-e608211f4c16",                        [{"name":"0","source":"...\u002f4PZAsSKEBaGPZC8NowDHhhG\u002fDCsEWIEtlkD9XdzKrKyjnzzREvpht3\u002fMYzn+PfD\u002f5n\u002f\u002fn\u002fVpRfiDCVqxaXN14+SMuZRz9YzNgldKOPpH89SmjufmzkSZ8WuWQD7LPkzlsFxFNgnuHwtIG2orKzvzD4X5csAkWAPALiOupo4puQPS79XQsywH8Fdcfe\u002fpV+LEo4a2pL2YXNfg3jsmubNGNQ3SvJ25b0\u002fa4Zl1zrj4HbQapJsTT4o2L31iSng\u002f\u002fLJN63YQy8wVLF5LAQizYcDoZT\u002fx1BE+NcAlLJTiPeFnGu6Vd+uA6xlBhjvSVsVKJTorc2\u002fZrST9dxVqhLnS7S+rDGezPyioFige+4ZjITzDW6G6fJkZ\u002f12ZutKpk3C4v+JMNft6GK4EMCXzB6z+prjDhnX+zUKamOSFPDWJbkLXD3tug1DBlWb5H7wO29chAx\u002f+dYXhE0bdMv6HBmo0RFnrpnpn9Hkh+QPaI5Yd5foVcVeOStTcFOyaDEg9xmefZ9hz707jukoKCVz174zbwp0qQf4A6JWaZYwp0Ohuv6Jjk+gGEDnI7lg7hc+PTEgStsJIUVUNdif4Y6taGehcOkRi73PUqDO+f2IJhNTMgALoohtVlp3GWGPwNhrJK\u002fm6j3NSIQZnZ4TcBzzOYKvEfp90O2ynvKCFHosVIIDCKterrq1EHrOqoxTbl3A1LpeRh+Uxa7\u002fe7lyj2hybWh7XQYNeZxl\u002fw1iFMAaKqf1JP\u002fwNxnUW0FfEryO2uNkIfIv9rVXUifZZODXN5fAlWqH2v2j1AqQ\u002f8FgJ+itGL1D57l0t8Q9zRPVSfSRBIObjo4xxFo87coTjA4JeSFRvOE7PfhKCG\u002fYybZkl3mJxLXyP96Yv+1YYnpi4Q9zvDfLOBebwzC96bFVVifhoIRZGp9LaB28AT43wX0n9IEpfILB0CDd\u002fvobGk\u002fHNtLQG8931iDY76H2g+j+P\u002fE9jfefzvD+YYCiH8DkCf2L7lzhj7A5K2y3+f4H8d+bEZmpH+6jX+uyR\u002fy8E4eLxqeEGUdeI75Q2\u002f\u002fhJP\u002fC4YPcZi07m9BsQ\u002faD4TUNDmH\u002fa6PczqeWGrA9pixa4tz57cAtyqozJ06OCpA7OhXoP+nFp0P5ZdT9bkD30PIGJ5r9zpBqUobvhXEP+mzEDuIk4sQ340hSVkzoCsQMO5HKbm6YBz+y\u002f\u002fyMYvvC7btYdAAcxcQttZkhCET+pzVwZ0YMIr8GzIcecdlustNjOwYhB+Yf8fha2ZnBuuIczGYLl9VwGtdqHgPII\u002foBfCPo5EwVSQsoWmdK8ts2IRDrHrIbyAUyo8i5CnZYoASc71m70QrEF9TgqCm2CDNcq0JTc6BOZnGfgchxOuARx5fF\u002f1sgxDFFUODMWmAjmUhygIk16TNFCeV3Q5kXwDcxFepLaC4C\u002fFdqUNKx9LeeMI5N1jnBgoEVURLFw8w2gb30MMfYfwkj9c7o0BS48ADDMSwQCAIOWWNtQGHUaTrXWgnvIiDgejE2hSQ54R13J8EB3oxBJ9yX0F866AA7iaSGYocaoqTa+\u002fvQ7xRTnPfBvhzgK9T90FH\u002f422+yk6ZbBz4YbizMlo+ciAG4EV4Y+79ltOATdaJXsUCm8VNAWkJHhGkrXBpbM9JdYZnsAGBeOCQKEL6EOEA5SvXZJiftH3BxBMsOgnZr4Fz1j4ULrfivTX0HDLbineIWdDnEWbBjNy8etU5J3FUIyc3aZhPOCO2SLSPyB9wMVIB2zBIsQljk+TSC1IMCxc\u002fHcI79tYxPBDhj8IMZN+i\u002fGU1TdDxUvmvUHeeUCvsf\u002fc+Y1HIQuthPsla7dKMnIY8RLSzO5aniegudb8IMCa8WMlNwz0gE0CATgc+zggsObGDezI6y8E\u002fgfOXWEEfASQz1OjevQNwycIHwKzDGQMzCZinKimTU4RvUKxcHKC4+tIaELmymkgfOhrihkFSwM\u002fIvZCRYWxh\u002fgxBG1ARWo6j5WGc46ilT8RnkHsoCdWWNBTTUkGgLcwT2DjRIaoVQrAGPAZjH90qQRyVsROQofcFJJgfYaLzrmJ800C10GeBCIL9nZwH3jYU6Cs3QP4KktK58Yq3AXQJ14BvWeyKkKe4sbaGDWyFLP4E\u002faPBiGAuSUs4cGH2PViBlXI1AII4P0hZA57BONrB04AHgV4EYzmcR9RAoz1VCg4yfFPWrcQFMqdpUk0DhIWELBA\u002fqTIFNn3kFgmpkUJHBN4Z+MbaPYLd4mTGgUPceKdmeavwvCA2m9Z9yx1xzRUMJVVqGIceU08HW\u002fhfmoPEFxCPHhz6PIhj2VtxhgcAHNDw8SbX3PxXSquMthT1+pkTnm+tWlwXU5TSgTxHweaBP6Ts\u002ftB2wA+T5BM6AWO+307g1TCdFAYCDCBZBHQ64ZJ6hbIPVaeJ\u002fI4Fdsx3GdwKbwo2VcgnKh6F8GlUnNGBQn7GjQEAAmfMX4s0Z8OxBlUQ\u002fraQEeQEOkQwkNFhM23TuhCzbA+ICFAPxF44txLi6+qjBXxA6KWNJYWBx905C2lCUQHGioM9ydAoeGEFc878tyzaxdnAT5sgFMgMH0\u002f+pcAvAD2HYL2MZtim3p3ZAmriWT82tr7NDzw\u002fGkfvoO2s6NX3oyoX8T8BxPqLhYtR5F3AoiCPiDxIypl4OMxoIo8QVaG7kQkncXjzvzUW6djrzqDXc1jR+KJpND5iQmnN+AKprUMa00OPKyC\u002fRnwbR93WI9b14nwrgIuox+azffKf4\u002fkUyxvTXcsEQLALvm\u002fAmyzg0NOFsT+kEaBgOAtADTn4F8IPEJg58yOklNmCIwTmb4F5CYOX0P3AIFTF3aC\u002f8ah4NxauNcc8t34Jw6IM9oCsCArbu\u002fHxElbO0pM2GJKh+EO8\u002fsQ3MPwftTvBFx7I0D2iKJFHp9K40lyqqBF6pYGHF0P3A2K+RD2MKxRKBD9EcZ1Su4nMCeKa\u002f6OIO9af+bQix5e21Bruk\u002fMYNITGvaof+p7E9jXnkYItw4ijHTZc8xPuCu7eC8FG5uNWPI0hLloXwi3Fe65do2L8yRW3oEQGfGsssCCEqunlokM1pOgGVf9dpbEjca2B88TkTl8I+g+CGVEtvcfA4gcxwTfi8Lw3nj\u002fA4FHeLcXtQaI1tAFd0k9 ...
# Step 4 [total time 97.6s]: 0.3 Msamples/s (6.0M samples in 19.659s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="daba8b1a-b611-4afb-bdcb-622b9a1b38c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daba8b1a-b611-4afb-bdcb-622b9a1b38c1")) {                    Plotly.newPlot(                        "daba8b1a-b611-4afb-bdcb-622b9a1b38c1",                        [{"name":"0","source":"...\u002fABtrNDULmAiQQV8i3gAQXiCsLRLvlNkWdql110s5rrzxzGPELbw48D\u002fzP\u002f+f\u002fU1Z9w2lQN6hsXrX6uCk\u002fMfC3AhN6i2z1ZEhhWlrWv+z93JaVtDnmgIsbYpPFTzFcgTzvsZ0iv\u002fX\u002fkU3\u002fj6awYNgDQ8Wqe4sishd2\u002fKhU2cLs4Scx52L934VDLOGk7\u002fYovfLlZxC8HPquJmWMX9XgteNLpXohDjw49vq+ojmVG+efVjb0gqb4TuTjHNGQWuKNYM8FeDfQT4PeEHyZ4JH2V00c6WZBomWsSem9NUNOtZdL4GzKdAI\u002fl+adnr4S6dl9\u002frS03ziJZFe2+HAmf+Bu7068KQxbMTGOSQ1Zil\u002fG\u002fXfF295LEbLP6JSKV60pEfgXJL0EvIb6jtMa0g+tZWQ+I30PzGMJX8k8XqI3HEySsig9HqbfAVIJ9xkyCiGi5JrsisB6xAvJz9T2o4D\u002fCYVntDAopntkalBbjyqYnNm2\u002fHAaHtbkbzv+eQy3wCZJU5Cvw+4jXU6EvgHWC74wo0QUh14N7X1z+DTHAcTop5zcoCD3FfyOhjBK3PctPeVgiJ1Jgj5kK+OboChxcVvFMpkyC6zhZdVnVMEhphE6CPlYix9K0\u002fiEI61w\u002fzbgC0KmFn4kip8tiWXrqJxb+FjZm9iXzXwo763Z27aKApw5QckeOfgHmn9NmvWsdZv4FPBvQdGPh3Iwv+nFH2DuYCphfDqM\u002fiDDR8wZC5\u002fUoyHu2hAOZDb3\u002fXvGb8eTAurPthBU6bcG\u002f0VkVVLfAVij+oSsf5fZRyF+n\u002f1pWei+HktdM68VnOMMgv9tzvvIYjT+EMKnNEdb7FPwrdCgB1agJxptYvxkjv59yEdOS0JFja7uYWytL8heU63s5pRUNUE3yjkMbi38OMWvOf9XAbHGvc552Uo19XtD+KIyN2F0l+IKRzEUFen+WZb\u002frxw+cuHdXjzZEQDSEeBj4v8\u002fMvpBnkhwpdyuAl9GV\u002flaNuCfrvRfEfEdDX9eoHee2GinwXxNJy+8+RvO\u002fg8xP5HxUed\u002fxyoe1Wm0WfBrqrFBCJV1KFBeP2byjbECQA5w79KS5EnIkxkNA\u002fuRbP\u002fa5K1q3o7tSbTfEwEhfhzhjzSSJD3bjXOc2hIOihRsm\u002fJezjUn9x6DlHrZ14TcXvIj+G\u002f+i0cUfCHYUifnAadeI0JdYiXRPewKxBAoBn9E2I\u002fY1j5Mg9iUIUEyDvAd9o8iuqOBZcwTQXQX+8myTiI73oOTDB0mN8A\u002fyiGCWjF\u002flwP2ju7V96vwKEeT4S3G1MZDDHtCdphmYYcOnoYsAb6nZAQdwHHn0ImNhtIbkuZ1NC2YQLwCuPT4ZaVGW7QgjMjUJs8s5EQEZCXk93mYe+LKdGbpnsy4zXc8NFmsQHxkQ5SYqWxj4lJsUZhFkoNDmd1AsA8TCHEM8AUMXwn8\u002fc4QwnuUYYJJxKwpoP4A01vvCwAlgu0GtA0TxEAAT4MnAN8QdknjYQ5O8SrHgnkU2D0GHMZVJAuYi+wykj8k\u002fzkiygYj8LmzXya+Ltxnlvw7Bcd1\u002fBTCbcg3DBbBoExrj+44GjD7ypg\u002fEAqY7RQ\u002f4CBFT3MoCRMprAFHCRchbSnhPpnCdzmonMcQGJBfAAqguQLCA5aUKgCeQGInvtnBcwaea\u002fcHIX8TwzZjQ3kPLbIJkFBbLxG4LTBVEQG5iP6Sp8pgRgOP5I8y0IzHCSwUfovUHcKfU0gTyBDvxfS3FD2xKKLwreSfBN14CFEC0GxtY0ucgV8kdwOpQvHTGLtICU6XOT+tyu1S7SQ6hniFaOHbQASFamtoCVNLikdavREQBMIw3UOZxewg8Nwjy6bW\\u002fxY+hNba5jQUL8CDKHI4TpMuUx5DC5y5gDyw8J0dmmQEYGTip6Hv25D0cxHslisJFhrAnCyb429Ii6R4SdIYsRAoznGx9vs5nK+AYXNxmvEWhUGE3qqxxrrl8J93MRKhQfkfpunJBPBwZBj6ZL1FRhwZHCeOPsp3HcNuHAOZlIzfwZy6Po\u002fyUrPohiPckbmpeOz5mYt156eD+CkdEpSYeJEc92xE\\u002foJA644PBfjeE6PC9VdsYOupNYY+NKBJ4EdGjJdCghCZ9MPjQwyLGFyBpFSy18xatRDy2ui\u002fJl8P2t9G9pvEh7gc\u002fNDlxD2zPvyXkviVQ0h7rb0WeQzjmfUZkJMF\u002fAskRjr3P5xJ8kjFBdBTkawQUUl\u002fD+AyBg2wd5b+OaRaALd23iOVt8z3NYxdSBm4FDUsfZ9Jrc+PQ1uce8Nx2HwR7HPMIw4+S+zjhQUcLcI3RO4m\u002fGELHi19ouKXqHqeVCw5EjWwwaUjgAwkjxP7E8rsCPxX4wNlsxSmDez5NI\ ...
# Step 5 [total time 116.9s]: 0.3 Msamples/s (6.0M samples in 19.369s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ef109025-9e37-44f6-8a7d-5c81dd6b9701" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef109025-9e37-44f6-8a7d-5c81dd6b9701")) {                    Plotly.newPlot(                        "ef109025-9e37-44f6-8a7d-5c81dd6b9701",                        [{"name":"0","source":"...\u002f\u002fX\u002f+n\u002fFZh9KYtouT\u002fjHrTmaVc+H9HcSL1GrA3+h036iBAvfjvvDUAP3CbJKcqAeOSwIbFFeDiJMYuzCnzn0D1W1Qe0LNBZM3HhOwD7EioNlEeuE\u002fjJhLW\u002f\u002fvT8EVU7H\u002fpihzhcTgL3uvaSYwTkPg+drrY2oWXCNs9uKHqb6xpsvijR46kLYZSiZFiMOKq0Ye0XYe+1\u002f5uBepZ1HZcxrausgDwWJwA5weqst4AypuEHGWSon8Y+U+b2ffsbh9Ba+mPofvAhiUDt6uhQr6Wb34rfCyo1QCz\u002fTOkl2HA8\u002fqc\u002fMUB9oJGFRlNd7Pc\u002fwguY1QjjGoWQ50zAkR2outfPml4L+oCJao1bAIpqRpJk++B7Fcw4LNoADH8lI9EFkl0w1iXxC7VeO\u002fMfsn4ppwgatYV+xA6eTgtroS4MPJvgJp3\u002fj+D\u002fL8S6ObSEbL96l\u002foUhofAPMU64VLZkVEtInW47sSgUcgZ8nnNyJXDRbPInEtxRFrpd0yMJcTrYK87+lG1Nru56ehxSV+AhuzKxoosf67HMhbZRTcmRSY3nV6WvQxo1E3xcZdwCjzo+r+o3hqayj4xduPxY+5\u002fScC5nq2azNdU4aBo4U1XIw8uE\u002fidAf0rK3Wyr9+RXlP1NKLDqQwj\u002fuud\u002fC5mxhEw6DPWtDCXLzsU\u002fbiaXYaUHPG8yuh3el6SfzGbIvm5DW9C3Dr+K3PnuA6WPSDnD+5+waOzwxuPzRpBQA9UHWG+8aHI+NO6\u002fJ\u002fCcOEHqDz5+SePoylNB\u002fga14Ejk8aQTexJ\u002fPRf\u002fTpsj7iRiVOHrDYU+pDLPlKLDnquCUUw7c8fJjYGXKF5J\u002fjpgmLqrGMe2xJOwDHEhbO+qTymOKQmtKjn8MvPfZn+h\u002fQ+H7GmHCuQRKirmv+fxNhRPcXbGvSnRLwIUgZ2W\u002ft+v8x9F8ZN0\u002f1yRW09Mtgm7P9Dp06B\u002fjej\u002fE9iMu686\u002f9ui8WF\u002f5kjiZGCD8jgxibsCk+3LqvymMycIOMIapbeZlgFNlxn37GvS\u002fanNSlef6l4m9C0tZhmVDH1OcZpIy\u002fRhtixNVafrovwYuwnhM0xCoCGFu1qXmd7dlkfwb\u002f\u002fqgqBf1vSmTyighgSHCdU5TXDXybbIHKGJtsdE\u002fk7oWocilklYQlnl808cncaocSoY0Z5K0nbDFNWBZk8Gtsg2YGEzarALqUwsbqKl2ZFp9X4XH+dIgGwyojHUGBATHaGG+TTkWcgKkTVlc2oQRvucD3oASlc0qArlNpUEPQBbePi9Mk9bUgsKIg\u002fej4YcMt5yWyO5isNFwF6id56dqJy7uCKxoGobw5kLsSK8yyZlTLmnIHKexdwSuI\u002fxEFGRAs5kD\u002f4LSj4NZo+5QmgHRAmLRmWUP0q4y2GGsc5k2EbbcIwNQuhZTgZBJPInHqYpWk2XKTUisCBucMIQY8Izjz2zEuQPIZwzosZ4r+gm+C8C25TdE1f\u002fnYkXZWoQQSleUXQcHEoUe7yVOFN2MZrfMdZQd2f5IUUox4D8WWYe+R4L58kEZc\u002f46H0vkgVfxZQJDDm\u002fADoB920ULjHqxhqJgmA+0XJLPij0S+\u002f\u002fGuSf5WCB9sDWNBAXJA6VjwWkVZGNwZMsFtFfi8wslTwKS34oQh0JIehwIG9BrwBecTJNyHkqcfw9x+eGBuI+K\u002fIoOBmoI0EF2wW1VxKyP05mA1ST\u002fDLFPhGC0XWC84ratd0yvqQQMbZxLDBn2V46mJM4kOqZ63\u002fH6dKRgNmcJx7QmKLnWUS69P5vFPzSoxuPEI2ZqwbGnYFbyk8ZPnHhEpMiBk6xE8Z3rGK0zZhl9xrl31uSazb3joAY4pgJjJJwk5\u002fx+JOLBoCCOsnpHqczkncR9xieU9qBeZ9JGQlDySfGcNx69JjlETlUlbjXRDLkAkc5EjIb4Z1izupUsWoMiecGYw2ZhMLYIHNaFPDbaCpElwJ\u002f5\u002fGfG9gWAbusAG84O6Lea9xm32NSUU8HnCUtqeyNFaDHICY0rhia9nzJ3XtKGaIiuQdPKxSpGleh9Nk\u002fxoKRaDO9y+48c4vdh4gyyUtOE\u002fbRwIGGScnb6K+T5xk9EUXvbUJMEEyy+2DpgvsTIj6gQWFMqYornx6SPZX4G1LcZnbNYGHTtOEewlIMt2X8RtoCp6ek2i18yrm0SCBcreOjMi4FX0dMknsc67HyJ9ZZRCo6jhSfR\u002f8XnA6U+yYGhlaJAxbzXZwGBA3ilEwVraI48GIFdhGHRfaSYhD4TuVpcgGqB0xETyZSzwEhn53mK4G+RqkZYcuHX\u002fLqqsILiISkKIr3KTS+jwZtxoCp9AAXETLNcod+4uIikpcjIAv3gJPBlJFaVnuRn\u002fg00eo9pXhiTk1YiDAwdCpQwPEdZq0qZiU9Y66g4VgDkbbMYs3JI0SjS21Oxdyv07iA6usofxv4OuVt8M82udD4gMACwmdH\u002fwnbrzKZZIpy2tkEkWItlBRrQyL3VYTTPn1PwmAXb4J7HsxHr\u002fYowpimQzlkuRbCV3SOUCXQx0xfSbaN+E8ZoiQ+UgVKZOH9dy4JQ9bJhISviXXS\u002f8KpaQxNJucbZlKdbb4a8COEznB8gvHeWU2t6Nmo0IGzPZe\u002fsN2PGb2h8QUb+9irlOsIeIA\u002fYLbu1QHhD9H9BrDKoeCjwgR4\u002fJeAa5S22v8k0BlKjNCDRP6Q0SC3v4P4hOcZGnrKfhHgyANW9h6xYqyuM576hFMMO1gJ\u002fziQzrh9oDfBdonSrvuJ8cc4npNc5vAzC3c63vNYMroW\u002fJedv6LiSwt7ZlqWRxttjhtsbUgpp0\u002fZl5ld09jX9BUnTTCNl+dSHKFwavIffNZB+ETmRAfHmcg4QoEGn8kbQohk3idGyFCYI8WZRGdDFhR+n5QM4jijQ9F31AHO36Q4EM+JRWl0Bp1kqsogU66xf+rRK4JuGmKJHMx+InEXgbh8J\u002fE+0reTIIYsEZ56syxx6+UDQsc6mDxuSFgnuIf+PEWSkRnIRQ7X3C9QrnH6ENyfJP0dQYjpiSTTBINIe8FPePrkzZc0zSL5FSEbQmnKrJF\u002fI0gm6HEYL8s4zpEv434gBywwgdvkKUUaHCvx ...
# Step 6 [total time 136.5s]: 0.3 Msamples/s (6.0M samples in 19.539s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cbe0d136-b354-41c9-943b-d1cf4bbaa40e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbe0d136-b354-41c9-943b-d1cf4bbaa40e")) {                    Plotly.newPlot(                        "cbe0d136-b354-41c9-943b-d1cf4bbaa40e",                        [{"name":"0","source":"...\u002f57J7bX\u002fOPlmZWVklyiCF6HEVXAUmpCgIQh06okeDCDrQIIJrkAJBIalcVlWaY7Zbey83\u002ffz9Z14\u002faOgyngf\u002fd\u002f\u002fr\u002f5WaXVc0DQN21feboVs0fzmF\u002f76xi+Qm5q9H\u002f7iYG+Qfp81pbmqVtsjzoMY2lakYrBzms2AOddZ9\u002fJ3Dfz+Tj5C+goAG905WmB9FFSEIj7HAf1Z4267\u002fh3CsZX3m9kYRx3qZ4WMaW6X3Wpxrl5x9SGPWTYK4GMKmE0fYjMU\u002fFyUmuc+xF2IhAvYqt25d1Hcgf8zprwDfqpI8pkKexuNg9FzkJN9o\u002fjsXEUoV7V7GbSBR8V\u002fJ8O+x+YT8+RavtP+p6JkNYQunZ2aD4epR\u002f3UXupVOy\u002fAse4fmZVn+ZO\u002fmRe0SlZI\u002fq+QPY1ygeJXYi+QiHeZKBEWugKgqPQ5TfFWZX+qBdjorPCruVuB8v3iv8qsGqzKmkJArMlPj5QF0LupOHv4SxH+b0xdlNlau3ugHA0cu5I4vXfgU8LxDo8Tfgv4rD0\u002fQgzbRmVvhvoxyktMEhZU5iZUXQwVpmsqgF7ZOTebVOJf1Y1eq4z39UfuywKUb7+ViRrnehHcz+Ve02qX5vpdHXNYagkjnrJqe\u002flgdlmi5FK6xDvAqie9tucrw0JOxaUU0AM58etbM\u002f95TsZsi7RcRGx+HMgozl6Z\u002fX4yd8pQVNjLFw2dZ\u002fXWG35ku1NuN098KeIvG0TgW\u002fOcj\u002fm0mbAtu4xG1a1GMKbrk39TdU95sJzxvMTwOD0bdzLvnOJ4ceGvtXUrPsun88KuWraqe8+YHslUoH11+Nlfz3KzYn9m8C1wFPIf43yP+Bjlocx3KX5R0D\u002fWRKn8Av0g0QukCeUXfLPBfDulEOVNsU9N+J9DnlRYzK0\u002fH7VC3EvHk4N5aFRycYX6n9atcqnl5H4oZpZ\u002fT2ZjqJoag3iOOAU6CnZnxiPFXhqVL\u002fTGdDJQgdVDNJP+Njvep\u002fZwSeX\u002fTwquAOsul5n99SP8s6\u002fc2\u002fgOjr5EPPsxF\u002fEE0x5m\u002fSfzfSXGq0nHIP9smu\u002fEoQtbUSmcSFmv3K4N6\u002f6ae\u002fTzsr1B4pg7KhyQA8XTBarD\u002f1u5\u002f63g+Vj+3rsplpeoql07hJ0CZAWFqxVjKXG3jbFE9sauEWJYyclOiT42rhfi4ajv8P\u002f6LN8hf1GYzckj5mDKjDCHbDm6mqlTAwEdDOlbqZ+XKmM+SHaqoSJ0x\u002fL3A5yX1xEojRkThhrGTVWyZ04QXFAY2wDCjtM8m2ryPcQ4pdtXNrrzG7ECskXSJOkNttEO1sYEOWOfSktiRmOmIjNuSlyOjVFsBumE5lEaWj0VdZPkH5Z6PcKYwGOpTlJ7I6AOFC1T32b3JYtD8vsgLC7DnFcWlqu9SeBWyayUeYOLSGDkhUuZTLqOgfS5QRI1sASYorwXeD+lOiBp4QBI2c69EFU\u002fZPBT3kvABBOzyrtUz8gCwTMyiFKruFBb2NEiDqaFioFmJ2EHZZDotclTToqh3JXdEi1D2Sjzm9GVQt01\u002fGZvvU\u002fmiKglpkcs7DZcxpCJtoJUVHsWV9z9qPQP\u002fmPUJ5sgAVOZZZBET68CkWEiFIee1LB5zHTNo6Tj8tkjGcA1WZEoxKFYLSVi7eqRfJX5X4l9j\u002fWUOisSGZE\u002fFxjRiOsvQoF9bGgM2bGyMowVwAlVpEnxqSpOEJlhM8B7DjvFFJeYRXEAhylstLwMdOPWNeO2TB6owF45br6bOypBqGB0aT+V1Zg8kBNwU+NzK\u002fT4MyracvRKqOAJt0T9NDJJZVOdu+lNFl0FmIaziecbIOWvMkZep\u002fMngq5QfCwaEIvUJTn2Ed8J+IdDGtENhIM819sJTr4hETwg5fsX8N0XaRnVpUlj1yUkJvRVq4Jcm\u002fJoAWZSiOpkHgDNRhkyDEq8EbSncZQIUqpSShcI0ZnGiuaSInQlDBkPLkAMzWNEc+FqZlCbRSOkzCmqpHIgxVSXGCnCu+W\u002fKVIF+rcXbiL8JYm2zirkBvNP6uYgPUynASEQyyYl6JY+VHAMjDzpLsLhivhxIGbjWZFDY6K+T7thrG2OstpBeCg1UCsMGyhWpkdL7UEDApZQs43bi50lpLTYp9ewt0EIbLCkU2SJJDp8iKVU+l\u002fJt8UBFtrpsIXwqw4ua\u002fg7sL6RuKpQBjiopIHVi2tX5Vx0qyZ9DvT7PyHwaWTIvtnFu80stSqTK5atYCxvaEB3AUuZ7oY5KelHTrRQ0j0nCpqgiRLUvSwDfJCHoSuNJVC\u002fB3GNY4jRLaUFgDO4NdiXJYicCMYkLE48RGk7oxKjy32Uxc3IrDn9u7EcrBHEtwKv6b0o+DQE9bMbSsN0DvchYSdYDfK\u002f1UaHnkX3Un4yYBuIaWluNgr+I5dK3Pyk1LKOOcFqVvSzPNHiMDySnSl018tJEKfLnh2JtEaBvmS9BP0WmwrLJG3YdNH+dmz9xdVfoU0jnu6gdzhBOCz+w\u002fUGPXxRGpq7wyo+UJAZdK71LQqk0S3jmyged+3x6DeUquU\u002fcDKLsHOhdtWM7aOsba5HPO\u002fhA4ksDd1l8LdABn9f1xLDg+KkkShRyllg+Uuhl\u002fG00Fz4uiF8\u002fYsptSDB68SaVisQ50+TCmkLV09biiZ9WyvzFuP+Q4E+yvJKulKFmflkkTeVXstNoL1HfpfBJUgvpxEwWRdHwzwsdEdy4+L0SrwAqIc4m+j0gVsMd5VeaT3lSVv5ZRFGEtmFNUo\u002ftE4hFKBWkajRrE78qIkzhCcRtKnuWYt\u002f\u002fSGKB8bXGM8hfBnGf4rXKjVHByj\u002fbpzur\u002fzzAg\u002fajjkMszHmNYRqTY7yJMQOtJYRK\ ...
# Step 7 [total time 156.5s]: 0.3 Msamples/s (6.0M samples in 19.993s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="97b95034-a65f-4f90-a17c-d23d33ecbb31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97b95034-a65f-4f90-a17c-d23d33ecbb31")) {                    Plotly.newPlot(                        "97b95034-a65f-4f90-a17c-d23d33ecbb31",                        [{"name":"0","source":"...\u002f0KruhoEPWAI6iFigtQDhvwEJOgSVSWKzIysjMiIOGZ789nXPe72iwHX37jwX\u002f\u002fr\u002f5Ww24q2Y1937cf9tFzYn6f8b60+c3mfw+sEjyujGe\u002fdVudGqzCCamf0a19GY5R2Jb4M9UMTeQjfTfjuRHyM8Ctw1sKjk0vOt8o+sjPBlFj+C5n2tv+z37A2tZ80FYF1m+nGj+dSb7V4qqbJV+\u002fiQLLLMl358LkRJ6WLeX6ly32wc\u002faZpJWuOsq5G3fZ\u002fkWWf6D0t4B\u002fpGKyGiEDuOvZzCeyeLzW8N7HiihkOWA4BNIW\u002fiWFv8fmjvDqUFoR7qE29ewP8PxEDRjlo\u002f7QhPQg+SQ9pzAm\u002fQte\u002fp2+f1nkY6ID5F8K+c\u002fRn6N6FekeQgbsV0o7KKOEWluapUtPrPzROj3pibEh\u002f1Vid+gGUy4NRnTWJ11qFhNkCYAT21GOr5j+PpVNanyb9Fb1Np3n3Ffh3JUx4kkrZwlfQXwb+CH5WOnW6y\u002fkv432Vg05lljZi6SBfZKBHO2URSu6EsvcieoxF7EZzE0VhgrPwrwXi06U6hD+sdX\u002fMj88lq5Puos5agBKIqtzh2\u002ftuEIDULyl6PjXRbwz5SLD9xNdmPyI+gHKJsRXbffvHHZ06KV9kaAtcShZ6qqi+S2plUt3WZFVHPfP0b5zfN1WovI3CX8t4E1WSD4U\u002fJtR\u002fEfmhU19T2tpHaVW4wzxdVsf3PEw4HlHtJveVXJq2hd5kg7Ami\u002fMncdlcV9Jrk1VlYe32K5KfnfM5ytclkVOUTQ4Or\u002fKZHP8\u002fxJ+K7hV6tMMryCPpbZ1fMeRslAclKdZq2+7\u002fB983oh0ClqQeHQCQk5KLLSx7m6qOlRis3fvDERv1pgG0ouc9IoPvnCWY02vZxdrgCg\u002fMuWcmqCtDk9Y\u002fIFwMwe5ku2UBhRN0kvLb0x+H\u002fRrAdb5bYNPI6giaiX\u002fw+z+OqhdE19JvWcIIXQm\u002fi42F7I88\u002fk\u002fSr2Q6UVMf2+ahU8SYga6lMmloo0Jh7q3u2eq2\u002ft+UewAcCLKGw8LwNUJu9H8g+z\u002fNmYczfva2SLudNMlV0txVBScFHKq4sSqwz0sF3riI5FZEntvA6Vcz7bIcacL\u002fu\u002f+218SXho6BDGFfKnjjCq7pFpxP1VUZy64nkND+r10yufLaA5VzkJcMvyJxDWnCQtqEWJZiXg3N62OteB5EtfoPamUsJV5ytqZHHO0pfimejjGZwhHhANJmdOyMChdJO1k0ROQy1bRJFRrQs6QuLQjFEVbok3HZSxalEPRqwJ\u002fVPHJjK1mQfIhxi4LMuqA7gTUHuN1JKfi16LPLbk+9zJ2ojnE8CrnwWoYyhZgrUVC5FxOmGdCXyAw6MI1cUG6IN5P+VYIQSUWUjpPk7R1egLqXYovAR5QimP+2opzChnwqrBHzKS2AgIHnmWDGbnUUO90PGe+z2IN5JRvsnxk1gBdgkHRl5y+i\u002fqhPlyG9g+JnzdZMnSF7xRexdgXSREftFCIFyH8JLWCdExySRkBiFgxNpQSmUMAA4K0KCXuZUkl61RyQ0Mqv8lAyJ\u002fByMwixZTVWmBcBD3Sg8CXHH7E+kUKRYgR9YhJxnSU8TLxEtJB05iZij3LyWmYPEgFbYQvTVFeEOEipjuR+0CnjXgaSx+FJP7B0AuP9xBdpV7F4oFN4cJxF+XQ2DrHOrmD0EjlklkwJZE+FPla0WGOWVYbzk6SKm4mo2LYJahlIbLGuY8VnHvFRGjhsuBUUlKkIsvIbyxcxnIERIBBqHPhXIQb1OcSqsg7ohXnRtORghnJCYkAc84\u002fI\u002f6HpGRD6+SXZLfJMWNfo3Hlhc4fEhEDg2pkOrK4pHSfhVDiJcKjKG8zdIihQMfkKfcJzwyImFQj3czZkHUZELSGMsCDsnPxnQURoCLKghNBjgpKqoCtpn+Ocy3UE4Ffovou4VGnOeUOhFPyGtOnwCiyB7KyJEdZkkUJXHJ2hgVp+szl0lGr8UZCIbl24ROoJQdts5\u002f1XoZLUTHmkmmi9ITsFnxf8CDSeVGsw3GG75LSRtzFlCBKwEbrwFlksRQ05fjISCI9Q31fXCEhiuQj5Ic0flvBj6n7UORO0yqWplKppNpM93X8YIIyvMHq03WJkC4j10zLPgiTrrWYCje+XEa71LNIqZRyBvGz0EvI5zV\u002fFJzbEgUcMzlBdkiSMbRxIei5hGcs1qR3GM7ZL0vYCG5rPFhaUxJsGFE52Ni8UNRBCjOB4h9QsKdbMX8j64+GKBIpDK39B4pN9hzRzUysj4AvsuxEySP\u002fIE0dxbcJx2jfSFEcUw1PjN5xuUxxGZp\u002fVmq7DirixkLS\u002fEpThjCguLfiiRGnMlYSr0YwtlTZfCrygtUuQM6cmgQ8K2i+z\u002fWfcvOZxceQVwNyljXiOfNE9rOaXxRMQCvkQ0gxCBGVNeIQCClUBZ75vDXBpbOfoPyspLtYbQWkGeTO3rLJ2ky1rSAt1vhGmSc2bwF\u002fI9ADL201glhwec8FHRQsjSg78gHyq1ivXK6Rrj5T5jolig5f+YRCnGZyMQySTY8HU0yck6hfzf29559EeWWmUKZlwedRmVn9QGr2ZknmNoevAmuI5yYsQASE37JYK5xzvFP6ouBSiecO\u002f30ibw\\u002fie6fJGOVG8Ed0r2kouW1TVuRXlBsmS61eCj0guGsM3+Gohj+CqeflgVX0VlxN+LCzFnZXY4XGg4qiUb8JGIVqmWmX6JEDbM3qCtSEHOCBSFjiCUhjlIdMeYQwGcJ8cHbn1x+DJ3C\u002f8O\u002f\u002fp8l09t85dUNRqjEEMYFNFxIiyypbCd7UYWvkkPMOiNZLk44w7nHTcWdgH5S53K6xxai3JN\u002fxnabpusFfvRQR ...
# Step 8 [total time 175.8s]: 0.3 Msamples/s (6.0M samples in 19.347s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b3e1956f-970d-4fcd-8b31-cc4f5d103ffe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3e1956f-970d-4fcd-8b31-cc4f5d103ffe")) {                    Plotly.newPlot(                        "b3e1956f-970d-4fcd-8b31-cc4f5d103ffe",                        [{"name":"0","source":"...\u002f0y03\u002f28+8dgw9D\u002f6X\u002f9X\u002f3rmd4+Mcm77dHpJduF8V\u002fleO3sV6lPIiybSyBvBL3NfanOkcQdmgeJUktEmVQPhmcnNXZUzfzvj5Qn+X5fd1RGN3mV4w\u002f+xsyqFyY0L6SyfVDT+k\u002fmjaixISsUPfZr1Po1cGGr3Amav7YZyM7YKWlzl88OqdLCaeviX5CXxKKStlKV4Osu3jc3X\u002fjPVPWN8CPhNb1E+ldlgWWc+dymyudLmN4KGQss+QQsDW0e8l\u002fVH7Aehs5DXFW2irTWWWVys31qAH+6FJtNXtqlxA3pN9X\u002fufzPa16C8ih4J\u002fpeVvSz2v5q3gDrLR+NCpVcZh8NigkriIcL6Qn1VcB3XP6sqmj4DdqRcrrYVZ4iaXRWkmihmRK0WypKZ34P7nmK6KH5e82euDr9cMt2q+iDBn2KxUUDhWdZl4r3Ky+nq237vydcRHipmpevuq2IST5Zyr2WrbaLJYMLStPwQw7kTR5LseLtJwgM3Cit\u002fGv1vZ\u002f6xud9DfBtMLsqmJyln1PvLOjRadZ35s0Ef4ttJnz1cZ\u002fzriN7Zu0e6kqMLf+O5\u002fZurqcbDudwUaTnciZ8YLzY+kXJSxamrMlI5fg\u002fn7WF92vXPpVPFXin+uVuG0FfMfz+pvhMCFcZAV+aTEap05vN00pzgcjuZykWGfjl7N7WpVdzppcO6EFU60grjT2jZuE\u002fY\u002fmuYl88djNUt8UfqRivZ1nPmSEFP635T6PaIYeC50k\u002fJsem\u002fKnvMByKbsKkRj\u002f7LP\u002f1PEV6qckR017U7EFQVrb3xbtgffbQytDvEHwqk2Swwn59YxrZdwTHxiPTX4TU7JgU3qETAVXrJlSldAnwTblLuV7lK+q26VqGll29TvAr00ys6ZOziP2IqqRv0p5vdRhkaujZkFdI5i4t+X5XvFL2v+n9C\u002f1PVVTP+\u002fpruIlaFoRSssO6gNNWnQo53fGvMcp3NuCiER\u002fzzJlaKrhTxP5m\u002f8+J\u002fkGie7bWuuEnVrZSTlQGGYdbSTrYFto3eqWZlYT2vtEHKKnaMamrAQNR0M43\u002f3X\\u002faq6rTtc5v7vmV81lRjXLA8OX8f8yNow7IxaCK5L\u002fmSMSJ0jWS9SBBB6gE6lQdoBxVW1NDTUcjKsmDmLNHSo5XcVDfGdchJZQ4XiOuTSp3ZSW0dXnG65veIA2hxYCVTkkk1uMrRQgPAZsAO7KnW2MCUwCG2Bx55NUgDY1\u002fKMdV\u002fVqxYuE04FmOR7rb9l2HPcO\u002feq1IrcCWEN99UG7xc1G44j2aT5TYGMSJR+Avdrg6cxV+PXVY5Wek5VmRjKxECanVhM8baBm2QLgXb4QjCXOjvqskCUHxt4leqTRhA6Id1QPiZ+1P6GuGV5ALwisEomKjQRIs0KsfA3BP\u002ffqhuPq5rW5J\u002fqDEK7RnyGr6h+YWLBCnql4xbcpeRH0a2mbzV8xHoH4ASZYSEqQX1ivHFQcrLemlCD1zgVryFrXAywtfqBy9phn0EQjZIJcM66pSyAKyV\u002f5LwAdaHhczVfF5ws11I9QzZ6BTJlLpoDq8bAmEURdmQyMOcZgYzVj8LXMxqLjwotapvTPRhX49LxIViyySpPyKboidIr8c8YdoJMtRdFNu9m\u002fIuqotNTqgEiKO2NwZoVmzXBocoJBFW6AD9zmMmopGUw9bFM\u002f6iRL7W7AzVb1Vfw3jQYqRnu23rbZu\u002fkivzHm8q1bIR0VVdDbhxvjLqvcBZpme2ZzgHqqcoa4rMyN1DPG35GUZ5JmYei2JIeuUOoLW\u002fInCu1VqpTZuT4GsOK00qxdThbuqRKbHpDksQ3vFS6x5IyKCXfIXGiScdXxt87BUmDherNfwBZxTQk5ARjbQ6kzotZmBqP+Uet1xn\u002fsmCu3SelKUnX1gtjDsKvE2Npf9KUV9UWXjmITr62ZCQxmkerb7x6YcpC6+UojedW3I+gezZ3M7CguGJl9tT8zP57aT6D3gduZtFZGzS+wBH1T2p+z\u002foE6lxkmPmQqRS9cuoxUotZGG4yDzZxOv8z1d9yGaU5IYSk1ME9oPXOJ+\u002fWwmrFP2i\u002fcPis8BtLuuLS+4y0AfxAqLPoxD3xLSYD8DI0KoIjvHqAFjtkpKS+CmWh3TqjlCAG1ZGeLNuYKrZv0\u002fg4wwcs7\u002f1cOTTMm2T7qHdkhuTXZJ9L3hKpmi9NulDIGv5QsDFwkPxgzOuKS4Png\u002fo3gNGPW5T3VoxkZZt\u002fllXMVJVsEaA0AfUNgpXKxRxs\u002fUpUDPmI6onNsoBM4UCkIetWfOHzrE5zndraNShO\\u002fG6wNXKfVfFAPwWTz8vubalOPU046tuPoIbczy39cnF0uE\u002fYFLFrdjekG48HqItvhs1mVLVBqvomlIFCNrNkCEVk+ZK+T62j1GepUf87\u002f+r\u002f6LYYyOLop5qMS0d4rSBvlSwqvYafpnNC1c+K1bMqiBaMVGnBk5HPnPUGi6TvjLzR+hc1E86vhe\u002fK+Gs56eIXUFWpmo+pPLO6o81vZHlz3h4D2oENyMPVc417QufWf4ywFeGfjLwbcFBJmhMKLAg87GCZQ1VL+ws ...
# Step 9 [total time 195.2s]: 0.3 Msamples/s (6.0M samples in 19.361s)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8143fe36-475e-4c9c-b758-b112b2ddc01b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8143fe36-475e-4c9c-b758-b112b2ddc01b")) {                    Plotly.newPlot(                        "8143fe36-475e-4c9c-b758-b112b2ddc01b",                        [{"name":"0","source":"...\u002fwpi+OPNNKf3Y3biE1AgkOCSG7W5YMG96yBJyA8R5ngXeQbLDc6c9rrblmGnl86U1PukNVscF1IBf+l\u002f\u002fF\u002f8G6o0MZE667h3H2wX1d8H9p4Luss8pF4ae1WyvdzcfBNFe4JPAx+byZa24rlUz4YrRzCzCWrwp82dovFV\u002fUUZ05VftS4L03tOQjBZPkz30mP3\u002fKzd52a1wWkZ00ouacp43xbMmFxZX2++XcWX8K9naZH6N9Lc0p51deniCWkk9kVlT8yOemHsD\u002fJdK7Kt+Q\u002fYKpB3\u002fUysAvihk7c+D4zKRzhuh4Elc4P1a8MPYVlZ+tr6D9BJbynTZ9yLzATe9HXdLiP\u002fkCJ9vFeivl0bs\u002f480\u002f2cdbNGfRSeg15j8WutZwo1JNSYbug9soj8cOGtlIxkW3G3pr5vWIT+TeuPw9SzuvGy\u002fk7Qjz9VwdxcpptlgqFmqtG74R\u002fz\u002fmdKVNauTFMXyJ+UXRtz7tZpCs7YWbSY24kPVMJQd6M7t3vr7J9i2es\u002fo2mMvqRptjLSNbtT56lyStUtP4071z7ZGs518ausjDEftrA+aU\u002f3nl\u002fvdyeKurxwlXBqqtReECg0vy5KeI\u002flL4ozOO9auCn1p4xfj3M\u002f7a1U\u002fks3JJ\u002fKpv\u002fz2bKz7fu\u002fAvWCPUnzlvTOft8hZcW2DMYHo3pOlbA39c9KpZbbrlUOEbNW\u002fRGJkq+d+M+pPG5M9l4sa2C+DWurPMv93Ez\u002fl8HMxNh\u002fa0JGceu9Utn9xixtYLSB3JUTpj8J62+fTgmrXK\u002fszU0UrWEyRsUlrokgSz\u002fN6bX1XAFh6TPlv03MSGRLSelKoUn2Dx\u002fj\u002fvyv9Q4GvhxvkM+DiSAbLI4ppVvR+6fgX0\u002fJz\u002f4HHIcYPp0fk3ucQG9iBHDiXW70o9BfBsTgJzhVuxaPKOzM8FL7VqMGsuB7GY7WWnH7w8ZOld66fCHV9n2Kk5WPOl1stFMWLjaWbrymLd8ktuLwhutf49hRc2r1j\u002fo2tep3JCIaLXWA8gkeLjYJNP31lzLHMrfTYSgL+f8TXoaidPY\u002fcH\u002f\u002fQvi+YllqbsBb1vsi5WbbD4sJDY3MtSXLQnwrWzdfTOkIrJK8S8xHQl5jzEBf\u002frf\u002fNnQFeWRqGh6o3NJO7MdRvM59JMQVasbckG3c8mr1ius59aSaIbxI9At6ALyMrhULGjcsi9s7kxMo7+yg4DxVghWmbwIxYBDlWXlbs\u002f6i3RntiC9cJOxIQwKx193Y6YajbWKbhtKA9Vo+o6w+D1UdyrFh+X8sLCY7VR+d5ATHDlRIz7wrVnEG9Zaw+2UOkqgJaPFK\u002fWcHoCcRlNU2t5UengMMzlyZgrIgF0AqgKhIMahrqtgFgXcs+I54nfG2tRSIyJfJztJpZXQr+wvCG9E5tn+dK6l5qsgZcMR5QzhURYIJvJeuSq2mA4uHKrsFezBvRUBOxeOBBRlWjoE9c34o\u002f2GMvqTyqvWkmVdignhze53qvxDA\u002fWXCNc1vq9dawiBaJXU6GIBsLW5lGbihqL8R6z8L2DVjgVgIgT1z+rVC0fKORFIlTU2CJrV\u002fqZPnm64XwvbQdLS+FJ0AErcwplncBiAaTPhDfq2lKPgTSDMRoVPwVuihHAy8IfLE+FbjvdJsMM2ehbMt8IHXQ5BnddFEkaJdL0kO3UxJ7rCvIBXHb1poCCCab8CO7XjpZzmaNvCySnDWZVN1RGAUAFcibnfdCL5KsHMHiNSMwHSzsWTvBTo18X\u002fmKIgRbAC8p50U8+3pBesnxU2DrqUGbDugCKrRaU9Teo\u002f1OlEKnlemHcneQoNDWQk\u002f7K8r0YFJjQrG1+BHepfADrCX5j4SeSo2JQFcZWzWL4yHjlcKq5C9ZkkcaWsbYGrSM46znSZ+Ybh21FQGwsHBGWbIhqi9Ah\u002fC2Ua7CXRj+K+6bgwTKqOKWMdIVSqyxGq5JxelowWFyTrSBcFoNE1hwEuqzW0mQB0UCtj2yNpq3TPXvjUqDgALUQuXKl4QnSIFpJIhhr65jNV2KSoamK6ELOOmuUWcSsiZLok0jAcknhLDOTCYvTxcmpTt8Gvdf+ZzAUyIm2xjSQuZnfO95HDRF2ED7dwlDKtdKFuKsx21C3znxR4wqEGoNbMpSTSk\u002fLPYVbKS8DvkclL9WEu4qTozppRyKx3pLdGbMh3IB9kukG07YWb6APhjz2VIqGtSXDKA036K8ND0kt6U+EnDH7fBH8wSOUMBvVGP8W5HaRpaBkOUks1q7F7UxN+\u002fpo7CrTvyhkuH9L0GbZNfDC2pPKK9Ys4b01ecsksnLKUV55EyERuE\u002fRvHRm58qFp4tJO88b9d8bb8HfLSggLtSVzmTin3LzTxw\u002fgSuLtIu21XRggsBo7L2dv1KTiW4YTiN8YiqVdsE8ZNhgOYg+W\u002fTBFebLz5a\u002fBt5zZOCUKJ\u002f8vbjog3XhAgRW8guFS4Nno99ZqsVaFyY0G8EPDk0CyAJWn2xhgF+nYJJujO7uwGo7g3azeTalzruramotmUD2+A7FLGWS5rqk\u002fYQ\u002fU\u002f51XESXHvgqu7bgA\u002fkph526T7V+sISSL5rcEY6sf8YYjD1AeevpeUZvcXey\u002f1HxHKYvoN8FaCC3Jv5VdqkiGB0RfIlq3FciTjkvdu\u002f4ubi88ILwvtimwDylkwGtbFuyotfZLlnHKI3FuTF\u002fcy6fvfu1wtgsxqlWvhd51LIsdAfyTgQAHz0J0lekr4VB4pu2+Y7qV+I+aDkpfllwxemU\u002fUC2B\u002fKY0cgfibbORQImOvjytTeWcDfWHssf2FhWhHzhJ4sURe55YeJru4x1Wc\u002f0dVUXbUDtbXk+m2\u002fAfrbUYQelXgrkjFuCO4f3k8FVhSpbopXI1kHl+tbAy1LmkM6Va6UTzl8lWMAc2ASVvZUdyiXyrOUvTHlrQQOA12zonsA62Pr6aGBF7LQ2xj4xdapX2\u002fCDqkH8DS7vOqnrKsFOGb8LU4Y4lvLMp0PI1cM\u002fammKb8WviYKnsbgcw0zQI1MPCaiUlAAzBQtouGgewdQPtTkUGOqq4n\u002fzX\u002f5vss+NxkpPWmzj9sv0UtsjggfYGH6f\u002fDaWJ1QRiYwUhCZLDYwDdN ...
# GIF created at /content/force_map.gif
# <ipython-input-15-79edd57b48bc>:461: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
